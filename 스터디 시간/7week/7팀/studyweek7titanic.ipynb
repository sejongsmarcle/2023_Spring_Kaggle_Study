# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
#경고 무시
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df_train = pd.read_csv('/kaggle/input/titanic/train.csv')
df_test = pd.read_csv('/kaggle/input/titanic/test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_train.isnull().sum() #isnull()까지 했는데 cabin에만 true 여서 sum으로 해주었다.
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
msno.matrix(df = df_train.iloc[:,:])
# Out:
# <AxesSubplot: >

# %%
msno.bar(df = df_train.iloc[:,:])
# Out:
# <AxesSubplot: >

# %%
f, ax = plt.subplots( 1,2, figsize=(18,8))
df_train['Survived'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Pie plot - Survived')
ax[0].set_ylabel('')

sns.countplot(x='Survived',data=df_train, ax=ax[1])
ax[1].set_title('Count plot - Survived')
plt.show()

# %%
df_train[['Pclass', 'Survived']].groupby('Pclass').sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True).style.background_gradient(cmap='PuBuGn')
# Out:
# <style type="text/css">
# #T_68e65_row0_col0, #T_68e65_row1_col1, #T_68e65_row1_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_68e65_row0_col1 {
#   background-color: #ddd9eb;
#   color: #000000;
# }
# #T_68e65_row0_col2 {
#   background-color: #f8f0f7;
#   color: #000000;
# }
# #T_68e65_row1_col0 {
#   background-color: #faf1f8;
#   color: #000000;
# }
# #T_68e65_row2_col0 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_68e65_row2_col1 {
#   background-color: #ece2f0;
#   color: #000000;
# }
# #T_68e65_row2_col2 {
#   background-color: #88b3d5;
#   color: #000000;
# }
# #T_68e65_row3_col0, #T_68e65_row3_col1, #T_68e65_row3_col2 {
#   background-color: #014636;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_68e65">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_68e65_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_68e65_level0_col1" class="col_heading level0 col1" >1</th>
# ...

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_values(by='Pclass', ascending=True).plot().bar(x='Pclass', height='Survived')
# Out:
# <BarContainer object of 1 artists>

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar()
# Out:
# <AxesSubplot: xlabel='Pclass'>

# %%
y_position = 1.02
f, ax = plt.subplots(1, 2, figsize=(18,8))
df_train['Pclass'].value_counts().plot.bar(ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass', y=y_position)
ax[0].set_ylabel('Count')
sns.countplot(df_train, x='Pclass', hue='Survived', ax=ax[1])

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot(x='Sex', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')
plt.show()

# %%
df_train[['Sex','Survived']].groupby(['Sex'],as_index = False).mean().sort_values(by = 'Survived', ascending = True)
# Out:
#       Sex  Survived
# 1    male  0.188908
# 0  female  0.742038

# %%
pd.crosstab(df_train['Sex'], df_train['Survived'], margins=True).style.background_gradient(cmap='PuBuGn')
# Out:
# <style type="text/css">
# #T_a2b64_row0_col0, #T_a2b64_row0_col2, #T_a2b64_row1_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a2b64_row0_col1 {
#   background-color: #5aa2cb;
#   color: #f1f1f1;
# }
# #T_a2b64_row1_col0 {
#   background-color: #01746c;
#   color: #f1f1f1;
# }
# #T_a2b64_row1_col2 {
#   background-color: #7eb0d3;
#   color: #f1f1f1;
# }
# #T_a2b64_row2_col0, #T_a2b64_row2_col1, #T_a2b64_row2_col2 {
#   background-color: #014636;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a2b64">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_a2b64_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a2b64_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a2b64_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
# ...

# %%
#sns.factorplot('Pclass', 'Survived', hue='Sex', data=df_train, size=6, aspect=1.5)
#검색해도 원인을 찾지 못함,,ㅜㅜㅜㅜ
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 sns.factorplot('Pclass', 'Survived', hue='Sex', data=df_train, size=6, aspect=1.5)
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'

# %%
print('제일 나이 많은 탑승객: {:.1f}'.format(df_train['Age'].max()))
print('제일 나이 적은 탑승객: {:.1f}'.format(df_train['Age'].min()))
print('탑승객의 평균 나이: {:.1f}'.format(df_train['Age'].mean()))
# Out:
# 제일 나이 많은 탑승객: 80.0
# 제일 나이 적은 탑승객: 0.4
# 탑승객의 평균 나이: 29.7

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(df_train[df_train['Survived'] == 1]['Age'], ax=ax)
sns.kdeplot(df_train[df_train['Survived'] == 0]['Age'], ax=ax)
plt.legend(['Survived == 1', 'Survived == 0'])
plt.show()

# %%
f, ax = plt.subplots(1, 1, figsize=(7, 7))
df_train[['Embarked', 'Survived']].groupby(['Embarked'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax)
# Out:
# <AxesSubplot: xlabel='Embarked'>

# %%
df_train['FamilySize'] = df_train['SibSp'] + df_train['Parch'] + 1 
df_test['FamilySize'] = df_test['SibSp'] + df_test['Parch'] + 1

# %%
print("Maximum size of Family: ", df_train['FamilySize'].max())
print("Minimum size of Family: ", df_train['FamilySize'].min())
# Out:
# Maximum size of Family:  11
# Minimum size of Family:  1

# %%
f,ax=plt.subplots(1, 3, figsize=(40,10))
sns.countplot(x='FamilySize', data=df_train, ax=ax[0])
ax[0].set_title('(1) No. Of Passengers Boarded', y=1.02)

sns.countplot(x='FamilySize', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('(2) Survived countplot depending on FamilySize',  y=1.02)

df_train[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax[2])
ax[2].set_title('(3) Survived rate depending on FamilySize',  y=1.02)

plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
g = sns.distplot(df_train['Fare'], color='b', label='Skewness : {:.2f}'.format(df_train['Fare'].skew()), ax=ax)
g = g.legend(loc='best')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      0         A/5 21171   7.2500   NaN        S           2
# 1      0          PC 17599  71.2833   C85        C           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1
# ...

# %%
df_train['Ticket'].value_counts()
# Out:
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: Ticket, Length: 681, dtype: int64
