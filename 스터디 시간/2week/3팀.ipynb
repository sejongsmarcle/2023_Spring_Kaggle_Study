# %% [markdown]
# <a href="https://colab.research.google.com/github/sejongsmarcle/2023_Spring_Kaggle_Study/blob/main/%EC%8A%A4%ED%84%B0%EB%94%94%20%EC%8B%9C%EA%B0%84/3%ED%8C%80_2%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 최종: 338등
# pm10, pm2.5의 결측치를 수정하지 않았던 파일과 수정한 파일의 점수는 동일했습니다ㅠ

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
train = pd.read_csv('/content/Kaggle_Data/bike_train.csv')
test = pd.read_csv('/content/Kaggle_Data/bike_test.csv')
submission = pd.read_csv('/content/Kaggle_Data/bike_submission.csv')

# %%
train.head()
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   3    20                  16.3                     1.0                 1.5
# 1   6    13                  20.1                     0.0                 1.4
# 2   7     6                  13.9                     0.0                 0.7
# 3   8    23                   8.1                     0.0                 2.7
# 4   9    18                  29.5                     0.0                 4.8
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0               89.0                576.0           0.027           76.0
# 1               48.0                916.0           0.042           73.0
# 2               79.0               1382.0           0.033           32.0
# 3               54.0                946.0           0.040           75.0
# 4                7.0               2000.0           0.057           27.0
#
#    hour_bef_pm2.5  count
# 0            33.0   49.0
# ...

# %%
train.isna().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        2
# hour_bef_precipitation      2
# hour_bef_windspeed          9
# hour_bef_humidity           2
# hour_bef_visibility         2
# hour_bef_ozone             76
# hour_bef_pm10              90
# hour_bef_pm2.5            117
# count                       0
# dtype: int64

# %%
train[train['hour_bef_pm2.5'].isna()]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 14      28     1                  20.0                     0.0
# 33      56    21                  10.2                     0.0
# 46      78     1                  12.2                     0.0
# 84     130     1                   9.4                     0.0
# 100    149    16                  15.8                     0.0
# ...    ...   ...                   ...                     ...
# 1361  2047     1                  12.6                     0.0
# 1378  2066    11                  10.1                     0.0
# 1391  2086     1                  11.5                     0.0
# 1398  2096    20                  14.0                     0.0
# 1410  2114    22                  18.1                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 14                   1.8               58.0               2000.0
# 33                   0.5               84.0               1668.0
# ...

# %%
train.groupby('hour').mean()['hour_bef_pm2.5']
# Out:
# hour
# 0     30.982759
# 1           NaN
# 2     31.366667
# 3     31.466667
# 4     32.116667
# 5     31.525424
# 6     31.603448
# 7     31.779661
# 8     31.796610
# 9     31.616667
# 10    30.948276
# 11    30.827586
# 12    29.280702
# 13    29.946429
# 14    29.844828
# 15    28.741379
# 16    27.910714
# 17    28.553571
# 18    29.127273
# 19    28.338983
# 20    28.850000
# 21    29.694915
# 22    30.216667
# 23    30.593220
# Name: hour_bef_pm2.5, dtype: float64

# %%
train['hour_bef_temperature'].fillna({934:14.788136, 1035:20.926667 }, inplace = True)

# %%
train['hour_bef_precipitation'].fillna({934:0.016949, 1035:0.016667}, inplace = True)

# %%
train['hour_bef_windspeed'].fillna({18:3.281356, 244:1.836667, 260:1.620000, 376:1.965517, 780:3.278333, 934:1.965517, 1035:3.838333, 1138:2.766667, 1229:1.633333}, inplace = True)

# %%
train['hour_bef_humidity'].fillna({934:58.169492, 1035:40.450000}, inplace = True)

# %%
train['hour_bef_visibility'].fillna({934:1434.220339, 1035:1581.850000}, inplace = True)

# %%
train['hour_bef_ozone'].fillna({44:0.060362, 122:0.060579, 140:0.025167, 422:0.058508, 451:0.060362, 532:0.036817, 537:0.025300, 595:0.030367, 631:0.057400, 645:0.029317, 868:0.060579, 897:0.045203, 1035:0.058508, 1211:0.060579}, inplace = True)

# %%
train['hour_bef_ozone'].fillna(0.0321275, inplace = True)

# %%
train['hour_bef_pm10'].fillna({100:57.315789, 129:53.847458, 140:61.083333, 169:57.315789, 344:57.355932, 489:59.589286, 532:59.344828, 537:56.533333, 566:59.344828, 595:60.300000, 597:59.589286, 607:53.118644, 645:56.150000, 751:56.875000, 753:57.086207, 865:57.086207, 884:56.875000, 897:59.589286, 923:57.315789, 934:55.881356, 1035:56.875000, 1356:56.875000, 1090:59.344828, 1107:58.283333, 1163:59.589286, 1222:57.355932, 1301:56.875000, 1338:53.847458, 1398:53.118644}, inplace = True)

# %%
train['hour_bef_pm10'].fillna(57.178383, inplace = True)

# %%
train['hour_bef_pm2.5'].fillna({33:29.694915,100:27.910714,129:28.338983,140:30.948276,169:27.910714,192:31.796610,234:28.553571,273:30.948276,344:28.741379,489:29.946429,532:29.280702,537:31.779661,566:29.280702,595:30.827586,597:29.946429,633:29.844828,645:31.603448,672:31.525424,680:27.910714,751:29.127273,753:28.553571,784:31.796610,791:29.844828,820:30.593220,855:31.603448,865:28.553571,884:29.127273,897:29.946429,910:28.741379,923:27.910714,932:32.116667,934:30.982759,937:29.280702,948:30.948276,953:31.779661,1035:29.127273,1050:30.827586,1053:31.616667,1056:29.127273,1090:29.280702,1107:29.844828,1163:29.946429,1173:31.525424,1181:31.603448,1218:31.366667,1222:28.741379,1226:29.127273,1231:30.593220,1264:28.553571,1301:29.127273,1304:31.466667,1316:30.982759,1338:28.338983,1378:30.827586,1398:28.850000,1410:30.216667}, inplace = True)

# %%
train['hour_bef_pm2.5'].fillna(31.174713, inplace = True)

# %%
test.isna().sum()
# Out:
# id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            0
# dtype: int64

# %%
test[test['hour_bef_pm2.5'].isna()]
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 18     42    18                  29.4                     0.0
# 32     82     1                  22.8                     0.0
# 40    115     1                  21.5                     1.0
# 47    147     1                  22.8                     0.0
# 86    260     1                  20.0                     0.0
# 92    270     1                  20.0                     0.0
# 102   297     1                  15.1                     1.0
# 114   323     1                  18.7                     0.0
# 126   352     1                  19.2                     0.0
# 128   356    15                  25.5                     0.0
# 129   358     1                  23.6                     0.0
# 137   391    15                  29.0                     0.0
# 209   609     1                  18.6                     0.0
# 223   643     1                  16.8                     0.0
# ...

# %%
train.groupby('hour').mean()['hour_bef_pm2.5']
# Out:
# hour
# 0     30.982759
# 1     31.174713
# 2     31.366667
# 3     31.466667
# 4     32.116667
# 5     31.525424
# 6     31.603448
# 7     31.779661
# 8     31.796610
# 9     31.616667
# 10    30.948276
# 11    30.827586
# 12    29.280702
# 13    29.946429
# 14    29.844828
# 15    28.741379
# 16    27.910714
# 17    28.553571
# 18    29.127273
# 19    28.338983
# 20    28.850000
# 21    29.694915
# 22    30.216667
# 23    30.593220
# Name: hour_bef_pm2.5, dtype: float64

# %%
test['hour_bef_temperature'].fillna({653:19.704918}, inplace = True)

# %%
test['hour_bef_precipitation'].fillna({653:0.032787}, inplace = True)
test['hour_bef_windspeed'].fillna({653:3.595082}, inplace = True)
test['hour_bef_humidity'].fillna({653:43.573770}, inplace = True)

# %%
test['hour_bef_visibility'].fillna({653:1576.688525}, inplace = True)

# %%
test['hour_bef_ozone'].fillna({212:0.057400, 386:0.053344, 637:0.045203, 653:0.053967, 658:0.053344}, inplace = True)

# %%
test['hour_bef_ozone'].fillna(0.0321275, inplace = True)

# %%
test['hour_bef_pm10'].fillna({18:56.875000, 128:57.355932, 137:57.355932, 182:59.589286,237:53.847458,571:57.315789, 653:53.847458}, inplace = True)

# %%
test['hour_bef_pm10'].fillna(57.178383, inplace = True)

# %%
test['hour_bef_pm2.5'].fillna({18: 29.127273,128: 28.741379,137:28.741379,237:28.338983,571:27.910714,653:28.338983}, inplace = True)

# %%
test['hour_bef_pm2.5'].fillna(31.174713, inplace = True)

# %%
train.isna().sum()
# Out:
# id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            0
# count                     0
# dtype: int64

# %%
features=['hour','hour_bef_temperature','hour_bef_precipitation', 'hour_bef_windspeed', 'hour_bef_humidity', 'hour_bef_visibility', 'hour_bef_ozone', 'hour_bef_pm10', 'hour_bef_pm2.5']

X_train = train[features]
y_train = train['count']
X_test = test[features]

# %%
model300_20_5_2 = RandomForestRegressor(n_estimators = 300, max_depth = 20, min_samples_split=5, random_state = 0)

# %%
model300_20_5_2.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=20, min_samples_split=5, n_estimators=300,
#                       random_state=0)

# %%
ypred = model300_20_5_2.predict(X_test)

# %%
submission['count'] = ypred
submission.to_csv('model300_20_5_2.csv', index = False)
