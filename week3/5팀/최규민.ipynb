# %% [markdown]
# <a href="https://colab.research.google.com/github/sejongsmarcle/2023_Spring_Kaggle_Study/blob/main/week3/5%ED%8C%80/%EC%B5%9C%EA%B7%9C%EB%AF%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 버스 운행시간 데이터를 활용한 데이터 분석
# - 버스가 다음 정류장에 도착하기 위해서 걸릴 시간을 예측

# %% [markdown]
# ## 1. 라이브러리 및 데이터
# ## Library & Data

# %%
## matplotlib 사용시 한국어 나오게 하는 코드

# !apt -qq -y install fonts-nanum > /dev/null
#한국어 깨짐 방지 코드

import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'

font = fm.FontProperties(fname=fontpath, size=9)

# fm._rebuild()

# 그래프에 retina display 적용

# %config InlineBackend.figure_format = 'retina'

# Colab 의 한글 폰트 설정

plt.rc('font', family='NanumBarunGothic')
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
import pandas as pd #판다스 패키지 불러오기
import lightgbm as lgb
import folium

# %%
# 데이터 불러오기
train = pd.read_csv('/content/drive/MyDrive/smarcle kaggle study db/버스 운행시간/train.csv')
test = pd.read_csv('/content/drive/MyDrive/smarcle kaggle study db/버스 운행시간/test.csv')
submission = pd.read_csv('/content/drive/MyDrive/smarcle kaggle study db/버스 운행시간/submission.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. 탐색적 자료분석
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### pd.DataFrame.head()
#  - 데이터 프레임의 위에서 부터 n개 행을 보여주는 함수
#  - n의 기본 값(default 값)은 5

# %%
train.head()
# Out:
#    id        date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0  2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1  2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2  2019-10-15  405136001  7997025    360-1     33.458783     126.557353
# 3   3  2019-10-15  405136001  7997025    360-1     33.479705     126.543811
# 4   4  2019-10-15  405136001  7997025    360-1     33.485662     126.494923
#
#   now_station now_arrive_time  distance     next_station  next_latitude  \
# 0     제주대학교입구             06시     266.0             제대마을      33.457724
# 1        제대마을             06시     333.0            제대아파트      33.458783
# 2       제대아파트             06시     415.0            제주대학교      33.459893
# 3   남국원(아라방면)             06시     578.0  제주여자중고등학교(아라방면)      33.484860
# 4         도호동             07시     374.0              은남동      33.485822
#
#    next_longitude  next_arrive_time
# 0      126.554014                24
# 1      126.557353                36
# 2      126.561624                40
# 3      126.542928                42
# 4      126.490897                64

# %% [markdown]
# + id : 고유 id
# + date : 버스 운행 날짜
# + route_id : 버스 노선 ID
# + vh_id : 버스 id
# + route_nm : 버스 노선 실제 번호
# + now_latitude : 현재 정류소의 위도
# + now_longitude : 현재 정류소의 경도
# + now_station : 현재 정류소 이름
# + now_arrive_time : 현재 정류장에 도착한 시간
# + distance : 현재 정류장에서 다음 정류장까지 실제 이동한 거리
# + next_station : 다음 정류소 이름
# + next_latitude : 다음 정류소의 위도
# + next_longitude : 다음 정류소의 경도
# + next_arrive_time : 다음 정류장에 도착할 때 까지 걸린 시간(단위:초)으로 답안 제출을 위해서 예측해야 되는 값

# %%
test.head()
# Out:
#        id        date   route_id    vh_id route_nm  now_latitude  \
# 0  210457  2019-10-29  405136001  7997025    360-1     33.457724
# 1  210458  2019-10-29  405136001  7997025    360-1     33.458783
# 2  210459  2019-10-29  405136001  7997025    360-1     33.478867
# 3  210460  2019-10-29  405136001  7997025    360-1     33.478850
# 4  210461  2019-10-29  405136001  7997025    360-1     33.480700
#
#    now_longitude  now_station now_arrive_time  distance next_station  \
# 0     126.554014         제대마을             07시     333.0        제대아파트
# 1     126.557353        제대아파트             07시     415.0        제주대학교
# 2     126.483833  한라중학교/부영아파트             08시     417.0      대림2차아파트
# 3     126.488350      대림2차아파트             08시     334.0    연동대림1차아파트
# 4     126.489933    연동대림1차아파트             08시     550.0        케이티앤지
#
#    next_latitude  next_longitude
# 0      33.458783      126.557353
# 1      33.459893      126.561624
# 2      33.478850      126.488350
# 3      33.480700      126.489933
# 4      33.482077      126.485355

# %%
submission.head()
# Out:
#        id  next_arrive_time
# 0  210457                 0
# 1  210458                 0
# 2  210459                 0
# 3  210460                 0
# 4  210461                 0

# %% [markdown]
# ### pd.DataFrame.tail()
#  - 데이터 프레임의 아래에서 부터 n개 행을 보여주는 함수
#  - n의 기본 값(default 값)은 5

# %%
train.tail()
# Out:
#             id        date   route_id    vh_id route_nm  now_latitude  \
# 210452  210452  2019-10-28  405328102  7983486    281-2     33.255783
# 210453  210453  2019-10-28  405328102  7983486    281-2     33.248595
# 210454  210454  2019-10-28  405328102  7983486    281-2     33.251891
# 210455  210455  2019-10-28  405328102  7983486    281-2     33.251084
# 210456  210456  2019-10-28  405328102  7983486    281-2     33.248487
#
#         now_longitude   now_station now_arrive_time  distance  \
# 210452     126.577450          비석거리             21시     528.0
# 210453     126.568527         동문로터리             21시     280.0
# 210454     126.560303  서귀포시 구 버스터미널             21시     114.0
# 210455     126.559551     아랑조을거리 입구             21시     223.0
# 210456     126.511195       대륜동주민센터             21시     189.0
#
#            next_station  next_latitude  next_longitude  next_arrive_time
# 210452            삼아아파트      33.251896      126.574417                96
# 210453      매일올레시장 7번입구      33.249753      126.565959                50
# 210454        아랑조을거리 입구      33.251084      126.559551                16
# 210455            평생학습관      33.249504      126.558068                38
# 210456  서귀포버스터미널(가상정류소)      33.249091      126.509224                24

# %% [markdown]
# ### pd.DataFrame.shape
#  - 데이터 프레임의 행의 개수와 열의 개수가 저장되어 있는 속성(attribute)

# %%
print(train.shape)
print(test.shape)
print(submission.shape)
# Out:
# (210457, 14)
# (91774, 13)
# (91774, 2)

# %% [markdown]
# ### pd.DataFrame.info()
# - 데이터셋의 column별 정보를 알려주는 함수
# - 비어 있지 않은 값은 (non-null)은 몇개인지?
# - column의 type은 무엇인지?
#  - type의 종류 : int(정수), float(실수), object(문자열), 등등 (date, ...)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210457 entries, 0 to 210456
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                210457 non-null  int64
#  1   date              210457 non-null  object
#  2   route_id          210457 non-null  int64
#  3   vh_id             210457 non-null  int64
#  4   route_nm          210457 non-null  object
#  5   now_latitude      210457 non-null  float64
#  6   now_longitude     210457 non-null  float64
#  7   now_station       210457 non-null  object
#  8   now_arrive_time   210457 non-null  object
#  9   distance          210457 non-null  float64
#  10  next_station      210457 non-null  object
#  11  next_latitude     210457 non-null  float64
#  12  next_longitude    210457 non-null  float64
#  13  next_arrive_time  210457 non-null  int64
# dtypes: float64(5), int64(4), object(5)
# memory usage: 22.5+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91774 entries, 0 to 91773
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               91774 non-null  int64
#  1   date             91774 non-null  object
#  2   route_id         91774 non-null  int64
#  3   vh_id            91774 non-null  int64
#  4   route_nm         91774 non-null  object
#  5   now_latitude     91774 non-null  float64
#  6   now_longitude    91774 non-null  float64
#  7   now_station      91774 non-null  object
#  8   now_arrive_time  91774 non-null  object
#  9   distance         91774 non-null  float64
#  10  next_station     91774 non-null  object
#  11  next_latitude    91774 non-null  float64
#  12  next_longitude   91774 non-null  float64
# dtypes: float64(5), int64(3), object(5)
# memory usage: 9.1+ MB

# %%
submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91774 entries, 0 to 91773
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                91774 non-null  int64
#  1   next_arrive_time  91774 non-null  int64
# dtypes: int64(2)
# memory usage: 1.4 MB

# %% [markdown]
# ### pd.DataFrame.describe()
# - 숫자형 (int, float) column들의 기술 통계량을 보여주는 함수
#
# - 기술통계량이란?
#  - 해당 column을 대표할 수 있는 통계값들을 의미
#
#
# - 기술통계량 종류
#  - count: 해당 column에서 비어 있지 않은 값의 개수
#  - mean: 평균
#  - std: 표준편차
#  - min: 최솟값 (이상치 포함)
#  - 25% (Q1): 전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 1/4번째 지점에 있는 값
#  - 50% (Q2): 중앙값 (전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 2/4번째 지점에 있는 값)
#  - 75% (Q3): 전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 3/4번째 지점에 있는 값
#  - max: 최댓값 (이상치 포함)
#
#
#
# - 이상치: 울타리 밖에 있는 부분을 이상치라고 정의함
#    - 아래쪽 울타리: $Q_1$ - $1.5 * IQR$
#    - 위쪽 울타리: $Q_3$ + $1.5 * IQR$
#    - $IQR$ = $Q_3 - Q_1$

# %%
train.describe()
# Out:
#                   id      route_id         vh_id   now_latitude  \
# count  210457.000000  2.104570e+05  2.104570e+05  210457.000000
# mean   105228.000000  4.052491e+08  7.988694e+06      33.434528
# std     60753.847139  9.132404e+04  6.774077e+03       0.102350
# min         0.000000  4.051360e+08  7.983000e+06      33.244382
# 25%     52614.000000  4.051365e+08  7.983093e+06      33.325283
# 50%    105228.000000  4.053201e+08  7.983431e+06      33.484667
# 75%    157842.000000  4.053201e+08  7.997041e+06      33.500197
# max    210456.000000  4.053281e+08  7.997124e+06      33.556167
#
#        now_longitude       distance  next_latitude  next_longitude  \
# count  210457.000000  210457.000000  210457.000000   210457.000000
# mean      126.603451     490.256100      33.434711      126.603687
# std         0.123961     520.563932       0.102224        0.123838
# min       126.473300      97.000000      33.244382      126.473300
# 25%       126.523900     291.000000      33.325283      126.524550
# 50%       126.551050     384.000000      33.484860      126.551050
# 75%       126.650322     542.000000      33.500228      126.650322
# max       126.935188    7461.000000      33.556167      126.935188
#
#        next_arrive_time
# count     210457.000000
# mean          85.380824
# std           85.051170
# min            6.000000
# 25%           44.000000
# 50%           66.000000
# 75%          102.000000
# max         2996.000000

# %%
#평균 도착예정시간 85초

# %% [markdown]
# ### pd.DataFrame.groupby()
#  - 집단에 대한 통계량 확인

# %%
len(train['now_station'].unique())
# Out:
# 348

# %%
#중복값 drop_duplicates() 함수로 제거
train[['route_id', 'vh_id']].drop_duplicates().groupby('route_id').count()
#노선 별로 운행되는 버스의 수(vh id per route id)
# Out:
#            vh_id
# route_id
# 405136001     10
# 405136002      5
# 405136007      1
# 405136012      3
# 405136521      6
# 405136522     15
# 405320111      3
# 405320112      5
# 405320113      1
# 405320114      5
# 405320115      1
# 405320116      6
# 405320117      2
# 405320118      1
# 405320121      1
# 405320122      4
# 405320124      3
# 405320126      2
# 405320127      5
# 405328101     11
# 405328102     14

# %% [markdown]
# ### folium.Map()
#  - location 옵션에 있는 좌표를 중심으로 지도 시각화

# %%
coord = [35.1559361, 129.1384361] #coordinate
map_osm = folium.Map(location = coord)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d69fbbdd58720dd5a066a9a56e2c744 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d69fbbdd58720dd5a066a9a56e2c744&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d69fbbdd58720dd5a066a9a56e2c744 = L.map(
#                 &quot;map_8d69fbbdd58720dd5a066a9a56e2c744&quot;,
#                 {
#                     center: [35.1559361, 129.1384361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8cc683b55cccc258401a6c1f3c219981 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8d69fbbdd58720dd5a066a9a56e2c744);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm = folium.Map(location=coord, zoom_start=12)   #zoom: default val == 10
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f045e95a59d06060ba331fd483d1c35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f045e95a59d06060ba331fd483d1c35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f045e95a59d06060ba331fd483d1c35 = L.map(
#                 &quot;map_9f045e95a59d06060ba331fd483d1c35&quot;,
#                 {
#                     center: [35.1559361, 129.1384361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc25a724466b93671b566de16e5bf100 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9f045e95a59d06060ba331fd483d1c35);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm = folium.Map(location = coord, tiles = 'Stamen terrain')  #ctrl + space
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_046f44bdbc89ff0f2bf399e07818e66c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_046f44bdbc89ff0f2bf399e07818e66c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_046f44bdbc89ff0f2bf399e07818e66c = L.map(
#                 &quot;map_046f44bdbc89ff0f2bf399e07818e66c&quot;,
#                 {
#                     center: [35.1559361, 129.1384361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ced54a0614ea29eae91357ce8038f185 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_046f44bdbc89ff0f2bf399e07818e66c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm = folium.Map(location = coord, tiles = 'Stamen Toner')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_260fc3b44f5f487019f2c090040d03b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_260fc3b44f5f487019f2c090040d03b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_260fc3b44f5f487019f2c090040d03b2 = L.map(
#                 &quot;map_260fc3b44f5f487019f2c090040d03b2&quot;,
#                 {
#                     center: [35.1559361, 129.1384361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9954270654825e57995fa2178cb3498 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_260fc3b44f5f487019f2c090040d03b2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 마커 생성
coord = [35.2335123, 129.0810047]
# 1. 지도 레이어 생성
map_osm = folium.Map(location=coord, zoom_start=12)
# 2. 마커함수로 마커 표시
folium.Marker(coord, popup='부산대학교', tooltip = '부산대학교 tooltip').add_to(map_osm) # 마커 생성 뒤 지도에 추가해주는 기능
# 3. html로 저장
map_osm.save('index.html')

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f73ea820345e5853bfd743d8415a7a7a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f73ea820345e5853bfd743d8415a7a7a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f73ea820345e5853bfd743d8415a7a7a = L.map(
#                 &quot;map_f73ea820345e5853bfd743d8415a7a7a&quot;,
#                 {
#                     center: [35.2335123, 129.0810047],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5dfcc5dbc12490d82ea62898173b4903 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f73ea820345e5853bfd743d8415a7a7a);
#
#
#             var marker_059723813563ac744051a9789e975a99 = L.marker(
#                 [35.2335123, 129.0810047],
#                 {}
#             ).addTo(map_f73ea820345e5853bfd743d8415a7a7a);
#
#
#         var popup_013130a3f63b61f93b533849a273ebdd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_768d18dedc6a36cb847fcf98bd875c4f = $(`&lt;div id=&quot;html_768d18dedc6a36cb847fcf98bd875c4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;부산대학교&lt;/div&gt;`)[0];
#                 popup_013130a3f63b61f93b533849a273ebdd.setContent(html_768d18dedc6a36cb847fcf98bd875c4f);
#
#
#
#         marker_059723813563ac744051a9789e975a99.bindPopup(popup_013130a3f63b61f93b533849a273ebdd)
#         ;
#
#
#
#
#             marker_059723813563ac744051a9789e975a99.bindTooltip(
#                 `&lt;div&gt;
#                      부산대학교 tooltip
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# default images: https://getbootstrap.com/docs/3.3/components/
#
# - 검색 기능이 없다
#
# fontawesome:https://fontawesome.com/icons?d=gallery
#
# - 해당링크의 무료인것만 쓸 수 있음

# %%
# 마커 아이콘 바꾸기
map_osm = folium.Map(location=coord, zoom_start=12)
folium.Marker(coord, popup='부산대학교', icon=folium.Icon(icon='star')).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e9379fc22bfe93cc5eabec7944b2fce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e9379fc22bfe93cc5eabec7944b2fce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6e9379fc22bfe93cc5eabec7944b2fce = L.map(
#                 &quot;map_6e9379fc22bfe93cc5eabec7944b2fce&quot;,
#                 {
#                     center: [35.2335123, 129.0810047],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_905f155e4ebec69d7fbd4842257178c1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6e9379fc22bfe93cc5eabec7944b2fce);
#
#
#             var marker_1dea254672057ee2cd4a6b0b75207042 = L.marker(
#                 [35.2335123, 129.0810047],
#                 {}
#             ).addTo(map_6e9379fc22bfe93cc5eabec7944b2fce);
#
#
#             var icon_893a4e6f0f95bff9b0029a0e9ce60b9f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1dea254672057ee2cd4a6b0b75207042.setIcon(icon_893a4e6f0f95bff9b0029a0e9ce60b9f);
#
#
#         var popup_0a62c4e32ff7ed0546a25b7a2405ee97 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_138645875209b6ba97e1e84a2136022c = $(`&lt;div id=&quot;html_138645875209b6ba97e1e84a2136022c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;부산대학교&lt;/div&gt;`)[0];
#                 popup_0a62c4e32ff7ed0546a25b7a2405ee97.setContent(html_138645875209b6ba97e1e84a2136022c);
#
#
#
#         marker_1dea254672057ee2cd4a6b0b75207042.bindPopup(popup_0a62c4e32ff7ed0546a25b7a2405ee97)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm = folium.Map(location=[37.541, 126.986], zoom_start=11)
folium.Marker([37.566345, 126.977893], popup='서울특별시청', icon=folium.Icon(color='red',icon='info-sign')).add_to(map_osm)
folium.Circle([37.4600, 126.9519], tooltip='서울대학교', radius=3000, color="green").add_to(map_osm)
folium.CircleMarker([37.5662, 126.9386], radius=10, popup='연세대학교',color="black", fill_color="crimson").add_to(map_osm) #마커랑 같음
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ebec9c6ec46d92485cc37b89450db125 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ebec9c6ec46d92485cc37b89450db125&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ebec9c6ec46d92485cc37b89450db125 = L.map(
#                 &quot;map_ebec9c6ec46d92485cc37b89450db125&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13fbd30a5086236ce7f60eef4b1e811c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ebec9c6ec46d92485cc37b89450db125);
#
#
#             var marker_fcd9a63bf28953efc263f53d1740b1c4 = L.marker(
#                 [37.566345, 126.977893],
#                 {}
#             ).addTo(map_ebec9c6ec46d92485cc37b89450db125);
#
#
#             var icon_d233881f1b57bd4bbc76e5a0ffaa66b8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fcd9a63bf28953efc263f53d1740b1c4.setIcon(icon_d233881f1b57bd4bbc76e5a0ffaa66b8);
#
#
#         var popup_be3c652e9e8ae4a3265530ec468a1aed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_474a37a9455dee599b453da653ea1c3b = $(`&lt;div id=&quot;html_474a37a9455dee599b453da653ea1c3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시청&lt;/div&gt;`)[0];
#                 popup_be3c652e9e8ae4a3265530ec468a1aed.setContent(html_474a37a9455dee599b453da653ea1c3b);
#
#
#
#         marker_fcd9a63bf28953efc263f53d1740b1c4.bindPopup(popup_be3c652e9e8ae4a3265530ec468a1aed)
#         ;
#
#
#
#
#             var circle_9d9f5dc057bca79d7fccbea1db27f353 = L.circle(
#                 [37.46, 126.9519],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ebec9c6ec46d92485cc37b89450db125);
#
#
#             circle_9d9f5dc057bca79d7fccbea1db27f353.bindTooltip(
#                 `&lt;div&gt;
#                      서울대학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_0947d2f9a2162ab30c83964d31e959d2 = L.circleMarker(
#                 [37.5662, 126.9386],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ebec9c6ec46d92485cc37b89450db125);
#
#
#         var popup_57c80959a3d11277478ed60721163e94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e655f02864af2e4239f1df0fc8d36d4 = $(`&lt;div id=&quot;html_0e655f02864af2e4239f1df0fc8d36d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;연세대학교&lt;/div&gt;`)[0];
#                 popup_57c80959a3d11277478ed60721163e94.setContent(html_0e655f02864af2e4239f1df0fc8d36d4);
#
#
#
#         circle_marker_0947d2f9a2162ab30c83964d31e959d2.bindPopup(popup_57c80959a3d11277478ed60721163e94)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm = folium.Map(location=[37.541, 126.986], zoom_start=11)

#폴리곤 마커 - number_of_sides attributes로 설정 / fill_opacity로 투명도 조절
folium.RegularPolygonMarker([37.566345, 126.977893], popup='서울특별시청', fill_color='red',color='red', number_of_sides=3, radius=30, fill_opacity=0.2).add_to(map_osm)
folium.RegularPolygonMarker([37.4600, 126.9519], popup='서울대학교', fill_color='green',color='green', number_of_sides=4, radius=10, fill_opacity=0.2).add_to(map_osm)
folium.RegularPolygonMarker([37.5662, 126.9386], popup='연세대학교',fill_color='blue',color='blue', number_of_sides=6, radius=10).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54624065b51a2a0f7911117bd2e26aef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54624065b51a2a0f7911117bd2e26aef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54624065b51a2a0f7911117bd2e26aef = L.map(
#                 &quot;map_54624065b51a2a0f7911117bd2e26aef&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4cccf3e58828d7e5cb8031fd2df77ae8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_54624065b51a2a0f7911117bd2e26aef);
#
#
#             var regular_polygon_marker_7abd2543adf3706adced9c4d8c5546db = new L.RegularPolygonMarker(
#                 [37.566345, 126.977893],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_54624065b51a2a0f7911117bd2e26aef);
#
#
#         var popup_b232182ce01508ba2db4b5f03f4a83eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_450f06e966902f034ff1d107cde02971 = $(`&lt;div id=&quot;html_450f06e966902f034ff1d107cde02971&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시청&lt;/div&gt;`)[0];
#                 popup_b232182ce01508ba2db4b5f03f4a83eb.setContent(html_450f06e966902f034ff1d107cde02971);
#
#
#
#         regular_polygon_marker_7abd2543adf3706adced9c4d8c5546db.bindPopup(popup_b232182ce01508ba2db4b5f03f4a83eb)
#         ;
#
#
#
#
#             var regular_polygon_marker_d040b79b24a3008ad16ac4565c3411a7 = new L.RegularPolygonMarker(
#                 [37.46, 126.9519],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_54624065b51a2a0f7911117bd2e26aef);
#
#
#         var popup_55e54409470b559632832789eeb35039 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31fe5b661b5395d749db93f2d0b8fe40 = $(`&lt;div id=&quot;html_31fe5b661b5395d749db93f2d0b8fe40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울대학교&lt;/div&gt;`)[0];
#                 popup_55e54409470b559632832789eeb35039.setContent(html_31fe5b661b5395d749db93f2d0b8fe40);
#
#
#
#         regular_polygon_marker_d040b79b24a3008ad16ac4565c3411a7.bindPopup(popup_55e54409470b559632832789eeb35039)
#         ;
#
#
#
#
#             var regular_polygon_marker_86ae3e47090224fbda4089c2a8bd7550 = new L.RegularPolygonMarker(
#                 [37.5662, 126.9386],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 6, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_54624065b51a2a0f7911117bd2e26aef);
#
#
#         var popup_49e0dc02473443c9e803ad6672e6f8ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_125c8e6d0a442175f54272e65baf4bfe = $(`&lt;div id=&quot;html_125c8e6d0a442175f54272e65baf4bfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;연세대학교&lt;/div&gt;`)[0];
#                 popup_49e0dc02473443c9e803ad6672e6f8ee.setContent(html_125c8e6d0a442175f54272e65baf4bfe);
#
#
#
#         regular_polygon_marker_86ae3e47090224fbda4089c2a8bd7550.bindPopup(popup_49e0d

# %%
map_data = train[['route_id','now_latitude','now_longitude','now_station']]
map_bus_route = map_data[map_data['route_id'] == 405136521].drop_duplicates("now_station")

# 맵 레이어 생성
map_osm = folium.Map(location=[33.4134, 126.5190], zoom_start = 10.5)

# map-bus_route를 리스트로 반복문 돌리기
for item in map_bus_route.index:
    lat = map_bus_route.loc[item,'now_latitude']
    long = map_bus_route.loc[item,'now_longitude']
    # 마커 생성
    folium.Marker([lat,long], popup = map_bus_route.loc[item,'now_station'],
                      icon = folium.Icon(color = 'red', icon = 'info-sign')
                      ).add_to(map_osm)

map_osm.save('index.html')

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5e8dcf87d1593bb6598f443f4950b8b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5e8dcf87d1593bb6598f443f4950b8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5e8dcf87d1593bb6598f443f4950b8b = L.map(
#                 &quot;map_d5e8dcf87d1593bb6598f443f4950b8b&quot;,
#                 {
#                     center: [33.4134, 126.519],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_336eaed72f06b52a4af34c837f51f43b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d5e8dcf87d1593bb6598f443f4950b8b);
#
#
#             var marker_06524d501f9a5a4ab2b6a80f0e3f547b = L.marker(
#                 [33.457848, 126.553938],
#                 {}
#             ).addTo(map_d5e8dcf87d1593bb6598f443f4950b8b);
#
#
#             var icon_c7dd737115958cf776276deb38c8ede9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_06524d501f9a5a4ab2b6a80f0e3f547b.setIcon(icon_c7dd737115958cf776276deb38c8ede9);
#
#
#         var popup_3d878f0c04b7b8666b2e97893d36a49e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_52c3da6ca75742747b46c8506ab23f05 = $(`&lt;div id=&quot;html_52c3da6ca75742747b46c8506ab23f05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제대마을&lt;/div&gt;`)[0];
#                 popup_3d878f0c04b7b8666b2e97893d36a49e.setContent(html_52c3da6ca75742747b46c8506ab23f05);
#
#
#
#         marker_06524d501f9a5a4ab2b6a80f0e3f547b.bindPopup(popup_3d878f0c04b7b8666b2e97893d36a49e)
#         ;
#
#
#
#
#             var marker_55442b761e486f3578852228bcda129a = L.marker(
#                 [33.456733, 126.55105],
#                 {}
#             ).addTo(map_d5e8dcf87d1593bb6598f443f4950b8b);
#
#
#             var icon_7f8b7058cb89a6332df28e865b6fa24d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_55442b761e486f3578852228bcda129a.setIcon(icon_7f8b7058cb89a6332df28e865b6fa24d);
#
#
#         var popup_6d59941863e6617b0639e54344d440f4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31b42771c0ed2cef5e51cfbd208f510f = $(`&lt;div id=&quot;html_31b42771c0ed2cef5e51cfbd208f510f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주대학교 입구&lt;/div&gt;`)[0];
#                 popup_6d59941863e6617b0639e54344d440f4.setContent(html_31b42771c0ed2cef5e51cfbd208f510f);
#
#
#
#         marker_55442b761e486f3578852228bcda129a.bindPopup(popup_6d59941863e6617b0639e54344d440f4)
#         ;
#
#
#
#
#             var marker_bdceca6cf7012d0aa5e050610cf0d4fe = L.marker(
#                 [33.462152, 126.549582],
#                 {}
#             ).addTo(map_d5e8dcf87d1593bb6598f443f4950b8b);
#
#
#             var icon_fcf0d2a5bfb491fdb9a8dc51bde3f6e6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bdceca6cf7012d0aa5e050610cf0d4fe.setIcon(icon_fcf0d2a5bfb491fdb9a8dc51bde3f6e6);
#
#
#         var popup_ed9780c4e0a13e3293c3a617b2496a05 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04bc3f850650a81f14ef18285d755946 = $(`&lt;div id=&quot;html_04bc3f850650a81f14ef18285d755946&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;남국사&lt;/div&gt;`)[0];
#                 popup_ed9780c4e0a13e3293c3a617b2496a05.setContent(html_04bc3f850650a81f14ef18285d755946);
#
#
#
#         marker_bdceca6cf7012d0aa5e050610cf0d4fe.bindPopup(popup_ed9780c4e0a13e3293c3a617b2496a05)
#         ;
#
#
#
#
#             var marker_8d9badfa307502264e1efef3f84b31f0 = L.marker(
#                 [33.464459999999995, 126.549248],
#                 {}
#             ).addTo(map_d5e8dcf87d1593bb6598f443f4950b8b);
#
#
#             var icon_537fbe8cfeb9527c5afa3784a7a66558 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &q

# %% [markdown]
# ## 3. 데이터 전처리
# ## Data Cleansing & Pre-Processing

# %% [markdown]
# ### pd.Series.str.slice()
# - Series 내에 문자열을 일괄적으로 slicing (자르기)

# %%
train['now_arrive_time']
# Out:
# 0         06시
# 1         06시
# 2         06시
# 3         06시
# 4         07시
#          ...
# 210452    21시
# 210453    21시
# 210454    21시
# 210455    21시
# 210456    21시
# Name: now_arrive_time, Length: 210457, dtype: object

# %% [markdown]
# data type이 object로 되어있음(원소가 int + 한글로 이루어졌기 때문)

# %%
train['now_arrive_time'].str.slice(stop=-1)
# Out:
# 0         06
# 1         06
# 2         06
# 3         06
# 4         07
#           ..
# 210452    21
# 210453    21
# 210454    21
# 210455    21
# 210456    21
# Name: now_arrive_time, Length: 210457, dtype: object

# %% [markdown]
# dtype이 정돈됨

# %%
# astype()함수로 dtype 변환
train['now_arrive_time'] = train['now_arrive_time'].str.slice(stop=-1).astype('int')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210457 entries, 0 to 210456
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                210457 non-null  int64
#  1   date              210457 non-null  object
#  2   route_id          210457 non-null  int64
#  3   vh_id             210457 non-null  int64
#  4   route_nm          210457 non-null  object
#  5   now_latitude      210457 non-null  float64
#  6   now_longitude     210457 non-null  float64
#  7   now_station       210457 non-null  object
#  8   now_arrive_time   210457 non-null  int64
#  9   distance          210457 non-null  float64
#  10  next_station      210457 non-null  object
#  11  next_latitude     210457 non-null  float64
#  12  next_longitude    210457 non-null  float64
#  13  next_arrive_time  210457 non-null  int64
# dtypes: float64(5), int64(5), object(4)
# memory usage: 22.5+ MB

# %%
test['now_arrive_time'] = test['now_arrive_time'].str.slice(stop=-1).astype('int')

# %% [markdown]
# ## 4. 변수 선택 및 모델 구축
# ## Feature Engineering & Initial Modeling

# %%
train.head()
# Out:
#    id        date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0  2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1  2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2  2019-10-15  405136001  7997025    360-1     33.458783     126.557353
# 3   3  2019-10-15  405136001  7997025    360-1     33.479705     126.543811
# 4   4  2019-10-15  405136001  7997025    360-1     33.485662     126.494923
#
#   now_station  now_arrive_time  distance     next_station  next_latitude  \
# 0     제주대학교입구                6     266.0             제대마을      33.457724
# 1        제대마을                6     333.0            제대아파트      33.458783
# 2       제대아파트                6     415.0            제주대학교      33.459893
# 3   남국원(아라방면)                6     578.0  제주여자중고등학교(아라방면)      33.484860
# 4         도호동                7     374.0              은남동      33.485822
#
#    next_longitude  next_arrive_time
# 0      126.554014                24
# 1      126.557353                36
# 2      126.561624                40
# 3      126.542928                42
# 4      126.490897                64

# %%
features = ['now_latitude', 'now_longitude', 'now_arrive_time', 'distance']
target = ['next_arrive_time']

# %%
x_train, x_test, y_train = train[features], test[features], train[target]

# %% [markdown]
# ## 5. 모델 학습 및 검증
# ## Model Tuning & Evaluation

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# %%
# dictionary 자료형에 모델 저장
model_dict = {
    'linear':LinearRegression(),
    'rf':RandomForestRegressor(random_state=0, n_jobs=-1),
    'lgbm':lgb.LGBMRegressor(random_state=0)
}

# %%
model_dict.keys()
# Out:
# dict_keys(['linear', 'rf', 'lgbm'])

# %%
model_result = {}

for key in model_dict.keys():
  print("---training....---")
  model_dict[key].fit(x_train, y_train)
  print('---predicting...---')
  model_result[key] = model_dict[key].predict(x_test)
# Out:
# ---training....---
# ---predicting...---
# ---training....---
# <ipython-input-64-a0b4b33033ba>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model_dict[key].fit(x_train, y_train)
# ---predicting...---
# ---training....---
# ---predicting...---

# %%
model_result
# Out:
# {'linear': array([[ 80.75162733],
#         [ 86.59637449],
#         [ 96.03730695],
#         ...,
#         [ 93.13399549],
#         [ 72.93764136],
#         [103.28646517]]),
#  'rf': array([ 35.36650507,  45.12237491, 135.88134374, ..., 126.37972036,
#          31.84467172,  88.46184286]),
#  'lgbm': array([ 42.12400643,  60.24878305, 120.81241189, ..., 105.81387439,
#          30.82952485, 111.66787953])}

# %%
model_result.keys()
# Out:
# dict_keys(['linear', 'rf', 'lgbm'])

# %%
lr_submit = submission.copy()
rf_submit = submission.copy()
lgbm_submit = submission.copy()

# %%
lr_submit['next_arrive_time'] = model_result['linear']
rf_submit['next_arrive_time'] = model_result['rf']
lgbm_submit['next_arrive_time'] = model_result['lgbm']

# %%
lr_submit.to_csv('lr_submit.csv', index=False)
rf_submit.to_csv('rf_submit.csv', index=False)
lgbm_submit.to_csv('lgbm_submit.csv', index=False)

# %% [markdown]
# ## 6. 결과 및 결언
# ## Conclusion & Discussion
