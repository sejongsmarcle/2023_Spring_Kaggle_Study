# %% [markdown]
# <a href="https://colab.research.google.com/github/sejongsmarcle/2023_Spring_Kaggle_Study/blob/main/%EB%B2%84%EC%8A%A4_%EC%9A%B4%ED%96%89%EC%8B%9C%EA%B0%84_%EC%98%88%EC%B8%A1__%EC%A0%84%EC%9C%A0%EC%A7%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 버스 운행시간 데이터를 활용한 데이터 분석
# - 버스가 다음 정류장에 도착하기 위해서 걸릴 시간을 예측

# %% [markdown]
# ## 1. 라이브러리 및 데이터
# ## Library & Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## matplotlib 사용시 한국어 나오게 하는 코드

# !apt -qq -y install fonts-nanum > /dev/null

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from pathlib import Path

fontpath = Path('/content/drive/MyDrive/SMARCLE/229611_버스 운행시간 예측 경진대회_data/NanumBarunGothic.ttf')
fontprop = fm.FontProperties(fname=fontpath, size=9)

# 그래프에 retina display 적용

# %config InlineBackend.figure_format = 'retina'

# Colab 의 한글 폰트 설정

plt.rc('font', family='NanumBarunGothic')
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
import pandas as pd #판다스 패키지 불러오기
import lightgbm as lgb
import folium

# %%
# 데이터 불러오기
train = pd.read_csv("/content/drive/MyDrive/SMARCLE/229611_버스 운행시간 예측 경진대회_data/train.csv")
test = pd.read_csv("/content/drive/MyDrive/SMARCLE/229611_버스 운행시간 예측 경진대회_data/test.csv")
submission = pd.read_csv("/content/drive/MyDrive/SMARCLE/229611_버스 운행시간 예측 경진대회_data/submission_제출양식.csv")

# %% [markdown]
# ## 2. 탐색적 자료분석
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### pd.DataFrame.head()
#  - 데이터 프레임의 위에서 부터 n개 행을 보여주는 함수
#  - n의 기본 값(default 값)은 5

# %%
train.head()
# Out:
#    id        date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0  2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1  2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2  2019-10-15  405136001  7997025    360-1     33.458783     126.557353
# 3   3  2019-10-15  405136001  7997025    360-1     33.479705     126.543811
# 4   4  2019-10-15  405136001  7997025    360-1     33.485662     126.494923
#
#   now_station now_arrive_time  distance     next_station  next_latitude  \
# 0     제주대학교입구             06시     266.0             제대마을      33.457724
# 1        제대마을             06시     333.0            제대아파트      33.458783
# 2       제대아파트             06시     415.0            제주대학교      33.459893
# 3   남국원(아라방면)             06시     578.0  제주여자중고등학교(아라방면)      33.484860
# 4         도호동             07시     374.0              은남동      33.485822
#
#    next_longitude  next_arrive_time
# 0      126.554014                24
# 1      126.557353                36
# 2      126.561624                40
# 3      126.542928                42
# 4      126.490897                64

# %% [markdown]
# + id : 고유 id
# + date : 버스 운행 날짜
# + route_id : 버스 노선 ID
# + vh_id : 버스 id
# + route_nm : 버스 노선 실제 번호
# + now_latitude : 현재 정류소의 위도
# + now_longitude : 현재 정류소의 경도
# + now_station : 현재 정류소 이름
# + now_arrive_time : 현재 정류장에 도착한 시간
# + distance : 현재 정류장에서 다음 정류장까지 실제 이동한 거리
# + next_station : 다음 정류소 이름
# + next_latitude : 다음 정류소의 위도
# + next_longitude : 다음 정류소의 경도
# + next_arrive_time : 다음 정류장에 도착할 때 까지 걸린 시간(단위:초)으로 답안 제출을 위해서 예측해야 되는 값

# %%
test.head()
# Out:
#        id        date   route_id    vh_id route_nm  now_latitude  \
# 0  210457  2019-10-29  405136001  7997025    360-1     33.457724
# 1  210458  2019-10-29  405136001  7997025    360-1     33.458783
# 2  210459  2019-10-29  405136001  7997025    360-1     33.478867
# 3  210460  2019-10-29  405136001  7997025    360-1     33.478850
# 4  210461  2019-10-29  405136001  7997025    360-1     33.480700
#
#    now_longitude  now_station now_arrive_time  distance next_station  \
# 0     126.554014         제대마을             07시     333.0        제대아파트
# 1     126.557353        제대아파트             07시     415.0        제주대학교
# 2     126.483833  한라중학교/부영아파트             08시     417.0      대림2차아파트
# 3     126.488350      대림2차아파트             08시     334.0    연동대림1차아파트
# 4     126.489933    연동대림1차아파트             08시     550.0        케이티앤지
#
#    next_latitude  next_longitude
# 0      33.458783      126.557353
# 1      33.459893      126.561624
# 2      33.478850      126.488350
# 3      33.480700      126.489933
# 4      33.482077      126.485355

# %%
submission.head()
# Out:
#        id  next_arrive_time
# 0  210457                 0
# 1  210458                 0
# 2  210459                 0
# 3  210460                 0
# 4  210461                 0

# %%
print(train['date'].min())
print(train['date'].max())
print(test['date'].min())
print(test['date'].max())
# Out:
# 2019-10-15
# 2019-10-28
# 2019-10-29
# 2019-11-05

# %% [markdown]
# ### pd.DataFrame.tail()
#  - 데이터 프레임의 아래에서 부터 n개 행을 보여주는 함수
#  - n의 기본 값(default 값)은 5

# %%
train.tail()
# Out:
#             id        date   route_id    vh_id route_nm  now_latitude  \
# 210452  210452  2019-10-28  405328102  7983486    281-2     33.255783
# 210453  210453  2019-10-28  405328102  7983486    281-2     33.248595
# 210454  210454  2019-10-28  405328102  7983486    281-2     33.251891
# 210455  210455  2019-10-28  405328102  7983486    281-2     33.251084
# 210456  210456  2019-10-28  405328102  7983486    281-2     33.248487
#
#         now_longitude   now_station now_arrive_time  distance  \
# 210452     126.577450          비석거리             21시     528.0
# 210453     126.568527         동문로터리             21시     280.0
# 210454     126.560303  서귀포시 구 버스터미널             21시     114.0
# 210455     126.559551     아랑조을거리 입구             21시     223.0
# 210456     126.511195       대륜동주민센터             21시     189.0
#
#            next_station  next_latitude  next_longitude  next_arrive_time
# 210452            삼아아파트      33.251896      126.574417                96
# 210453      매일올레시장 7번입구      33.249753      126.565959                50
# 210454        아랑조을거리 입구      33.251084      126.559551                16
# 210455            평생학습관      33.249504      126.558068                38
# 210456  서귀포버스터미널(가상정류소)      33.249091      126.509224                24

# %%
test.tail()
# Out:
#            id        date   route_id    vh_id route_nm  now_latitude  \
# 91769  302350  2019-11-05  405328102  7983486    281-2     33.493625
# 91770  302351  2019-11-05  405328102  7983486    281-2     33.495540
# 91771  302352  2019-11-05  405328102  7983486    281-2     33.498925
# 91772  302353  2019-11-05  405328102  7983486    281-2     33.500473
# 91773  302354  2019-11-05  405328102  7983486    281-2     33.499916
#
#        now_longitude   now_station now_arrive_time  distance next_station  \
# 91769     126.534764  제주지방법원(광양방면)             20시     272.0   고산동산(광양방면)
# 91770     126.532907    고산동산(광양방면)             20시     447.0   제주시청(광양방면)
# 91771     126.530351    제주시청(광양방면)             20시     418.0        광양사거리
# 91772     126.527103         광양사거리             20시     140.0  탐라장애인 종합복지관
# 91773     126.521348          용천마을             20시     541.0  제주버스터미널(종점)
#
#        next_latitude  next_longitude
# 91769      33.495540      126.532907
# 91770      33.498925      126.530351
# 91771      33.500473      126.527103
# 91772      33.500228      126.525625
# 91773      33.499190      126.516324

# %%
submission.tail()
# Out:
#            id  next_arrive_time
# 91769  302350                 0
# 91770  302351                 0
# 91771  302352                 0
# 91772  302353                 0
# 91773  302354                 0

# %% [markdown]
# ### pd.DataFrame.shape
#  - 데이터 프레임의 행의 개수와 열의 개수가 저장되어 있는 속성(attribute)

# %%
print(train.shape)
print(test.shape)
print(submission.shape)
# Out:
# (210457, 14)
# (91774, 13)
# (91774, 2)

# %% [markdown]
# ### pd.DataFrame.info()
# - 데이터셋의 column별 정보를 알려주는 함수
# - 비어 있지 않은 값은 (non-null)은 몇개인지?
# - column의 type은 무엇인지?
#  - type의 종류 : int(정수), float(실수), object(문자열), 등등 (date, ...)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210457 entries, 0 to 210456
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                210457 non-null  int64
#  1   date              210457 non-null  object
#  2   route_id          210457 non-null  int64
#  3   vh_id             210457 non-null  int64
#  4   route_nm          210457 non-null  object
#  5   now_latitude      210457 non-null  float64
#  6   now_longitude     210457 non-null  float64
#  7   now_station       210457 non-null  object
#  8   now_arrive_time   210457 non-null  object
#  9   distance          210457 non-null  float64
#  10  next_station      210457 non-null  object
#  11  next_latitude     210457 non-null  float64
#  12  next_longitude    210457 non-null  float64
#  13  next_arrive_time  210457 non-null  int64
# dtypes: float64(5), int64(4), object(5)
# memory usage: 22.5+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91774 entries, 0 to 91773
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               91774 non-null  int64
#  1   date             91774 non-null  object
#  2   route_id         91774 non-null  int64
#  3   vh_id            91774 non-null  int64
#  4   route_nm         91774 non-null  object
#  5   now_latitude     91774 non-null  float64
#  6   now_longitude    91774 non-null  float64
#  7   now_station      91774 non-null  object
#  8   now_arrive_time  91774 non-null  object
#  9   distance         91774 non-null  float64
#  10  next_station     91774 non-null  object
#  11  next_latitude    91774 non-null  float64
#  12  next_longitude   91774 non-null  float64
# dtypes: float64(5), int64(3), object(5)
# memory usage: 9.1+ MB

# %% [markdown]
# ### pd.DataFrame.describe()
# - 숫자형 (int, float) column들의 기술 통계량을 보여주는 함수
#
# - 기술통계량이란?
#  - 해당 column을 대표할 수 있는 통계값들을 의미
#
#
# - 기술통계량 종류
#  - count: 해당 column에서 비어 있지 않은 값의 개수
#  - mean: 평균
#  - std: 표준편차
#  - min: 최솟값 (이상치 포함)
#  - 25% (Q1): 전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 1/4번째 지점에 있는 값
#  - 50% (Q2): 중앙값 (전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 2/4번째 지점에 있는 값)
#  - 75% (Q3): 전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 3/4번째 지점에 있는 값
#  - max: 최댓값 (이상치 포함)
#
#
#
# - 이상치: 울타리 밖에 있는 부분을 이상치라고 정의함
#    - 아래쪽 울타리: $Q_1$ - $1.5 * IQR$
#    - 위쪽 울타리: $Q_3$ + $1.5 * IQR$
#    - $IQR$ = $Q_3 - Q_1$
#
#
# <img src="https://miro.medium.com/max/10125/1*NRlqiZGQdsIyAu0KzP7LaQ.png" width="700" height="500">

# %%
train.describe()
# Out:
#                   id      route_id         vh_id   now_latitude  \
# count  210457.000000  2.104570e+05  2.104570e+05  210457.000000
# mean   105228.000000  4.052491e+08  7.988694e+06      33.434528
# std     60753.847139  9.132404e+04  6.774077e+03       0.102350
# min         0.000000  4.051360e+08  7.983000e+06      33.244382
# 25%     52614.000000  4.051365e+08  7.983093e+06      33.325283
# 50%    105228.000000  4.053201e+08  7.983431e+06      33.484667
# 75%    157842.000000  4.053201e+08  7.997041e+06      33.500197
# max    210456.000000  4.053281e+08  7.997124e+06      33.556167
#
#        now_longitude       distance  next_latitude  next_longitude  \
# count  210457.000000  210457.000000  210457.000000   210457.000000
# mean      126.603451     490.256100      33.434711      126.603687
# std         0.123961     520.563932       0.102224        0.123838
# min       126.473300      97.000000      33.244382      126.473300
# 25%       126.523900     291.000000      33.325283      126.524550
# 50%       126.551050     384.000000      33.484860      126.551050
# 75%       126.650322     542.000000      33.500228      126.650322
# max       126.935188    7461.000000      33.556167      126.935188
#
#        next_arrive_time
# count     210457.000000
# mean          85.380824
# std           85.051170
# min            6.000000
# 25%           44.000000
# 50%           66.000000
# 75%          102.000000
# max         2996.000000

# %% [markdown]
# ### pd.DataFrame.groupby()
#  - 집단에 대한 통계량 확인
#
# <img src="https://s3.amazonaws.com/files.dezyre.com/images/Tutorials/Split+Apply+Combine+Strategy.png" width="700" height="500">

# %%
train.head()
# Out:
#    id        date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0  2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1  2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2  2019-10-15  405136001  7997025    360-1     33.458783     126.557353
# 3   3  2019-10-15  405136001  7997025    360-1     33.479705     126.543811
# 4   4  2019-10-15  405136001  7997025    360-1     33.485662     126.494923
#
#   now_station now_arrive_time  distance     next_station  next_latitude  \
# 0     제주대학교입구             06시     266.0             제대마을      33.457724
# 1        제대마을             06시     333.0            제대아파트      33.458783
# 2       제대아파트             06시     415.0            제주대학교      33.459893
# 3   남국원(아라방면)             06시     578.0  제주여자중고등학교(아라방면)      33.484860
# 4         도호동             07시     374.0              은남동      33.485822
#
#    next_longitude  next_arrive_time
# 0      126.554014                24
# 1      126.557353                36
# 2      126.561624                40
# 3      126.542928                42
# 4      126.490897                64

# %%
len(train['now_station'].unique())
# Out:
# 348

# %%
train[['route_id', 'vh_id']]
# Out:
#          route_id    vh_id
# 0       405136001  7997025
# 1       405136001  7997025
# 2       405136001  7997025
# 3       405136001  7997025
# 4       405136001  7997025
# ...           ...      ...
# 210452  405328102  7983486
# 210453  405328102  7983486
# 210454  405328102  7983486
# 210455  405328102  7983486
# 210456  405328102  7983486
#
# [210457 rows x 2 columns]

# %%
train[['route_id', 'vh_id']].drop_duplicates()
# Out:
#          route_id    vh_id
# 0       405136001  7997025
# 181     405136001  7997034
# 381     405136001  7997035
# 539     405136001  7997040
# 717     405136001  7997044
# ...           ...      ...
# 20226   405136522  7997004
# 26037   405320116  7983225
# 27098   405320122  7983067
# 45506   405328102  7983401
# 100467  405320114  7983091
#
# [104 rows x 2 columns]

# %%
train[['route_id', 'vh_id']].drop_duplicates().groupby('route_id').count()
# Out:
#            vh_id
# route_id
# 405136001     10
# 405136002      5
# 405136007      1
# 405136012      3
# 405136521      6
# 405136522     15
# 405320111      3
# 405320112      5
# 405320113      1
# 405320114      5
# 405320115      1
# 405320116      6
# 405320117      2
# 405320118      1
# 405320121      1
# 405320122      4
# 405320124      3
# 405320126      2
# 405320127      5
# 405328101     11
# 405328102     14

# %%
train[['route_id', 'next_arrive_time']]
# Out:
#          route_id  next_arrive_time
# 0       405136001                24
# 1       405136001                36
# 2       405136001                40
# 3       405136001                42
# 4       405136001                64
# ...           ...               ...
# 210452  405328102                96
# 210453  405328102                50
# 210454  405328102                16
# 210455  405328102                38
# 210456  405328102                24
#
# [210457 rows x 2 columns]

# %%
train[['route_id', 'next_arrive_time']].groupby('route_id').mean()
# Out:
#            next_arrive_time
# route_id
# 405136001         92.063688
# 405136002        108.270852
# 405136007         94.172947
# 405136012        111.322633
# 405136521        114.673939
# 405136522        101.339188
# 405320111         68.901710
# 405320112         67.602392
# 405320113         68.403649
# 405320114         66.634818
# 405320115         71.313237
# 405320116         68.122969
# 405320117         69.239122
# 405320118         67.643471
# 405320121         65.985019
# 405320122         63.955199
# 405320124         66.205659
# 405320126         66.512570
# 405320127         70.824370
# 405328101         87.579634
# 405328102         85.744862

# %%
train[['route_id', 'next_arrive_time']].groupby('route_id')['next_arrive_time'].mean()    # 같다!!!!!ㅋㅋㅋ
# Out:
# route_id
# 405136001     92.063688
# 405136002    108.270852
# 405136007     94.172947
# 405136012    111.322633
# 405136521    114.673939
# 405136522    101.339188
# 405320111     68.901710
# 405320112     67.602392
# 405320113     68.403649
# 405320114     66.634818
# 405320115     71.313237
# 405320116     68.122969
# 405320117     69.239122
# 405320118     67.643471
# 405320121     65.985019
# 405320122     63.955199
# 405320124     66.205659
# 405320126     66.512570
# 405320127     70.824370
# 405328101     87.579634
# 405328102     85.744862
# Name: next_arrive_time, dtype: float64

# %% [markdown]
# ### folium.Map()
#  - location 옵션에 있는 좌표를 중심으로 지도 시각화

# %%
coord = [35.1559361, 129.1384361]
map_osm = folium.Map(location = coord)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1164ce95994783e96b6c6f1a33b8e8cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1164ce95994783e96b6c6f1a33b8e8cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1164ce95994783e96b6c6f1a33b8e8cf = L.map(
#                 &quot;map_1164ce95994783e96b6c6f1a33b8e8cf&quot;,
#                 {
#                     center: [35.1559361, 129.1384361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7e77194834728b3a4700fdff4c618cb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1164ce95994783e96b6c6f1a33b8e8cf);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm = folium.Map(location=coord, zoom_start=12)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61a3a5d62be0dc81fc72ed7dec4f2cf4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61a3a5d62be0dc81fc72ed7dec4f2cf4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61a3a5d62be0dc81fc72ed7dec4f2cf4 = L.map(
#                 &quot;map_61a3a5d62be0dc81fc72ed7dec4f2cf4&quot;,
#                 {
#                     center: [35.1559361, 129.1384361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e300f992c055b5107c389b8cd1b28c9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_61a3a5d62be0dc81fc72ed7dec4f2cf4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #Stamen Terrain은 산맥이 드러나게 지도가 표시됨

# %%
map_osm = folium.Map(location = coord, tiles = 'Stamen Terrain')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43ff0d877540d96db53807f86cfbd9a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43ff0d877540d96db53807f86cfbd9a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43ff0d877540d96db53807f86cfbd9a2 = L.map(
#                 &quot;map_43ff0d877540d96db53807f86cfbd9a2&quot;,
#                 {
#                     center: [35.1559361, 129.1384361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d10cad1edcae5bab3aa79306796e932 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_43ff0d877540d96db53807f86cfbd9a2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Stamen Toner은 흑백으로 나타남.

# %%
map_osm = folium.Map(location = coord, tiles = 'Stamen Toner')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b9ab1244ab1d5cdfb3c21158bedca41f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b9ab1244ab1d5cdfb3c21158bedca41f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b9ab1244ab1d5cdfb3c21158bedca41f = L.map(
#                 &quot;map_b9ab1244ab1d5cdfb3c21158bedca41f&quot;,
#                 {
#                     center: [35.1559361, 129.1384361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30319f52a9add8478852c7b9a7105ae6 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b9ab1244ab1d5cdfb3c21158bedca41f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
coord = [35.2335123, 129.0810047]

map_osm = folium.Map(location=coord, zoom_start=12)

folium.Marker(coord, popup='부산대학교', tooltip = '부산대학교 tooltip').add_to(map_osm) # 마커 생성 뒤 지도에 추가해주는 기능
# popup은 클릭했을 때 나오는 팝업문구, tooltip은 커서를 올려놓았을 때 뜨는 문구.
map_osm.save('index.html')
# 구글코랩이 한글 호환이 잘 안되기 때문에 html로 다운받은 뒤에 그 html 창에서 확인한다!

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b7be7aca8c765898902045048175b7f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b7be7aca8c765898902045048175b7f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b7be7aca8c765898902045048175b7f = L.map(
#                 &quot;map_6b7be7aca8c765898902045048175b7f&quot;,
#                 {
#                     center: [35.2335123, 129.0810047],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7ff6aa9f6d9c2297820226709c7bfdb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6b7be7aca8c765898902045048175b7f);
#
#
#             var marker_6693bd0f2eed6ff69bcfb599a6fdf35c = L.marker(
#                 [35.2335123, 129.0810047],
#                 {}
#             ).addTo(map_6b7be7aca8c765898902045048175b7f);
#
#
#         var popup_d9eae754b6e0d525c5fe08fa3fcf33c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2de80705b0d5133c01934b437f7408f4 = $(`&lt;div id=&quot;html_2de80705b0d5133c01934b437f7408f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;부산대학교&lt;/div&gt;`)[0];
#                 popup_d9eae754b6e0d525c5fe08fa3fcf33c9.setContent(html_2de80705b0d5133c01934b437f7408f4);
#
#
#
#         marker_6693bd0f2eed6ff69bcfb599a6fdf35c.bindPopup(popup_d9eae754b6e0d525c5fe08fa3fcf33c9)
#         ;
#
#
#
#
#             marker_6693bd0f2eed6ff69bcfb599a6fdf35c.bindTooltip(
#                 `&lt;div&gt;
#                      부산대학교 tooltip
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# default images: https://getbootstrap.com/docs/3.3/components/
#
# - 검색 기능이 없다
#
# fontawesome:https://fontawesome.com/icons?d=gallery
#
# - 해당링크의 무료인것만 쓸 수 있음

# %%
map_osm = folium.Map(location=coord, zoom_start=12)
folium.Marker(coord, popup='부산대학교', icon=folium.Icon(icon='star')).add_to(map_osm)
#star 말고 나머지는 위의 링크에서 찾으면 됨
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f67df45acab2aba7b7779c475ac973e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f67df45acab2aba7b7779c475ac973e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f67df45acab2aba7b7779c475ac973e = L.map(
#                 &quot;map_0f67df45acab2aba7b7779c475ac973e&quot;,
#                 {
#                     center: [35.2335123, 129.0810047],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_144e490c899cdcb600fc72db6e5ba5bc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0f67df45acab2aba7b7779c475ac973e);
#
#
#             var marker_4daf9314655c715aa4dbf78d901b53e6 = L.marker(
#                 [35.2335123, 129.0810047],
#                 {}
#             ).addTo(map_0f67df45acab2aba7b7779c475ac973e);
#
#
#             var icon_2f4e71592c6c0be7c3f9b65b3cce17c9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4daf9314655c715aa4dbf78d901b53e6.setIcon(icon_2f4e71592c6c0be7c3f9b65b3cce17c9);
#
#
#         var popup_335116684f9bdf7f9e0559bd9b22f24f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_993bfa33a3efec0e33c36fc43388695a = $(`&lt;div id=&quot;html_993bfa33a3efec0e33c36fc43388695a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;부산대학교&lt;/div&gt;`)[0];
#                 popup_335116684f9bdf7f9e0559bd9b22f24f.setContent(html_993bfa33a3efec0e33c36fc43388695a);
#
#
#
#         marker_4daf9314655c715aa4dbf78d901b53e6.bindPopup(popup_335116684f9bdf7f9e0559bd9b22f24f)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm = folium.Map(location=[37.541, 126.986], zoom_start=11)
folium.Marker([37.566345, 126.977893], popup='서울특별시청', icon=folium.Icon(color='red',icon='info-sign')).add_to(map_osm)
folium.Circle([37.4600, 126.9519], tooltip='서울대학교', radius=3000, color="green").add_to(map_osm)
folium.CircleMarker([37.5662, 126.9386], radius=10, popup='연세대학교',color="black", fill_color="crimson").add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e18d3c16cc6fda4a8d7c3c380e2616b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e18d3c16cc6fda4a8d7c3c380e2616b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e18d3c16cc6fda4a8d7c3c380e2616b = L.map(
#                 &quot;map_2e18d3c16cc6fda4a8d7c3c380e2616b&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_336a7c1f2bd034294e10031ba253a719 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2e18d3c16cc6fda4a8d7c3c380e2616b);
#
#
#             var marker_321af43b57803dba7d59a5125a123af6 = L.marker(
#                 [37.566345, 126.977893],
#                 {}
#             ).addTo(map_2e18d3c16cc6fda4a8d7c3c380e2616b);
#
#
#             var icon_40234cfff516421c0014587479a91c03 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_321af43b57803dba7d59a5125a123af6.setIcon(icon_40234cfff516421c0014587479a91c03);
#
#
#         var popup_67593c4006da5e0ea188f03442d72d7c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1251ec4a56da0a919d9a448cbb962a95 = $(`&lt;div id=&quot;html_1251ec4a56da0a919d9a448cbb962a95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시청&lt;/div&gt;`)[0];
#                 popup_67593c4006da5e0ea188f03442d72d7c.setContent(html_1251ec4a56da0a919d9a448cbb962a95);
#
#
#
#         marker_321af43b57803dba7d59a5125a123af6.bindPopup(popup_67593c4006da5e0ea188f03442d72d7c)
#         ;
#
#
#
#
#             var circle_bb095de4dabf4c554c8915908e1ed976 = L.circle(
#                 [37.46, 126.9519],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2e18d3c16cc6fda4a8d7c3c380e2616b);
#
#
#             circle_bb095de4dabf4c554c8915908e1ed976.bindTooltip(
#                 `&lt;div&gt;
#                      서울대학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_8bdde0e79a09483957ce26edceb27271 = L.circleMarker(
#                 [37.5662, 126.9386],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2e18d3c16cc6fda4a8d7c3c380e2616b);
#
#
#         var popup_dc87e14d090a55fae6f96aba120aaf1d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ed3ec4ff6d864d98e3d4267d8ed5d75 = $(`&lt;div id=&quot;html_0ed3ec4ff6d864d98e3d4267d8ed5d75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;연세대학교&lt;/div&gt;`)[0];
#                 popup_dc87e14d090a55fae6f96aba120aaf1d.setContent(html_0ed3ec4ff6d864d98e3d4267d8ed5d75);
#
#
#
#         circle_marker_8bdde0e79a09483957ce26edceb27271.bindPopup(popup_dc87e14d090a55fae6f96aba120aaf1d)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm = folium.Map(location=[37.541, 126.986], zoom_start=11)
folium.RegularPolygonMarker([37.566345, 126.977893], popup='서울특별시청', fill_color='red',color='red', number_of_sides=3, radius=30, fill_opacity=0.2).add_to(map_osm)
folium.RegularPolygonMarker([37.4600, 126.9519], popup='서울대학교', fill_color='green',color='green', number_of_sides=4, radius=10, fill_opacity=0.2).add_to(map_osm)
folium.RegularPolygonMarker([37.5662, 126.9386], popup='연세대학교',fill_color='blue',color='blue', number_of_sides=6, radius=10).add_to(map_osm)
# number_of_sides로 삼각형, 사각형 등을 설정해줄 수 있다.
# fill_opacity로 도형 내부가 투명한지 불투명한지 설정 가능.
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5318f9a60a1539ad17c4c17147adb0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5318f9a60a1539ad17c4c17147adb0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5318f9a60a1539ad17c4c17147adb0d = L.map(
#                 &quot;map_f5318f9a60a1539ad17c4c17147adb0d&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61f0282931b6d06e26f8dc92f1f28ab8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f5318f9a60a1539ad17c4c17147adb0d);
#
#
#             var regular_polygon_marker_9dccfc12c2d8577f9b742cbe5517e138 = new L.RegularPolygonMarker(
#                 [37.566345, 126.977893],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f5318f9a60a1539ad17c4c17147adb0d);
#
#
#         var popup_20bad54f368c71dce8c66b32c19035d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f76bcf820d033b5a5cbd25683300930f = $(`&lt;div id=&quot;html_f76bcf820d033b5a5cbd25683300930f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시청&lt;/div&gt;`)[0];
#                 popup_20bad54f368c71dce8c66b32c19035d3.setContent(html_f76bcf820d033b5a5cbd25683300930f);
#
#
#
#         regular_polygon_marker_9dccfc12c2d8577f9b742cbe5517e138.bindPopup(popup_20bad54f368c71dce8c66b32c19035d3)
#         ;
#
#
#
#
#             var regular_polygon_marker_19e7e452ae53d687c7715cc710cc268c = new L.RegularPolygonMarker(
#                 [37.46, 126.9519],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f5318f9a60a1539ad17c4c17147adb0d);
#
#
#         var popup_1b5af81dc2ca3525f1d6c881b367a739 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_10b56f72b1afcd777d7eb0e5bb7f4ae0 = $(`&lt;div id=&quot;html_10b56f72b1afcd777d7eb0e5bb7f4ae0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울대학교&lt;/div&gt;`)[0];
#                 popup_1b5af81dc2ca3525f1d6c881b367a739.setContent(html_10b56f72b1afcd777d7eb0e5bb7f4ae0);
#
#
#
#         regular_polygon_marker_19e7e452ae53d687c7715cc710cc268c.bindPopup(popup_1b5af81dc2ca3525f1d6c881b367a739)
#         ;
#
#
#
#
#             var regular_polygon_marker_34644faf979f2982517fbf743be6eab8 = new L.RegularPolygonMarker(
#                 [37.5662, 126.9386],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 6, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f5318f9a60a1539ad17c4c17147adb0d);
#
#
#         var popup_3d4054884b9612900da18e4341d14c33 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dc7199c4e21c7d3077641c0f349e0d44 = $(`&lt;div id=&quot;html_dc7199c4e21c7d3077641c0f349e0d44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;연세대학교&lt;/div&gt;`)[0];
#                 popup_3d4054884b9612900da18e4341d14c33.setContent(html_dc7199c4e21c7d3077641c0f349e0d44);
#
#
#
#         regular_polygon_marker_34644faf979f2982517fbf743be6eab8.bindPopup(popup_3d405

# %%
map_data = train[['route_id','now_latitude','now_longitude','now_station']]
map_bus_route = map_data[map_data['route_id'] == 405320122].drop_duplicates("now_station")


map_osm = folium.Map(location=[33.4134, 126.5190], zoom_start = 10.5)


for item in map_bus_route.index:
    lat = map_bus_route.loc[item,'now_latitude']
    long = map_bus_route.loc[item,'now_longitude']
    
    folium.Marker([lat,long], popup = map_bus_route.loc[item,'now_station'],
                      icon = folium.Icon(color = 'red', icon = 'info-sign')
                      ).add_to(map_osm)

map_osm.save('index.html')

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4feda49ee42007eb14cd04b2cb870302 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4feda49ee42007eb14cd04b2cb870302&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4feda49ee42007eb14cd04b2cb870302 = L.map(
#                 &quot;map_4feda49ee42007eb14cd04b2cb870302&quot;,
#                 {
#                     center: [33.4134, 126.519],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7e2cc60e050cc34010342ba35716c15 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4feda49ee42007eb14cd04b2cb870302);
#
#
#             var marker_eb0a435ec77bd7ecdf68aaa418a5ddfc = L.marker(
#                 [33.449467, 126.91505],
#                 {}
#             ).addTo(map_4feda49ee42007eb14cd04b2cb870302);
#
#
#             var icon_f77052307658b380dc432101b9368a72 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_eb0a435ec77bd7ecdf68aaa418a5ddfc.setIcon(icon_f77052307658b380dc432101b9368a72);
#
#
#         var popup_a91d1011706b70ce5c8516dec951f784 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ec0f9f2d39c5627769e42d9a2dfe7b52 = $(`&lt;div id=&quot;html_ec0f9f2d39c5627769e42d9a2dfe7b52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;고성리제주은행&lt;/div&gt;`)[0];
#                 popup_a91d1011706b70ce5c8516dec951f784.setContent(html_ec0f9f2d39c5627769e42d9a2dfe7b52);
#
#
#
#         marker_eb0a435ec77bd7ecdf68aaa418a5ddfc.bindPopup(popup_a91d1011706b70ce5c8516dec951f784)
#         ;
#
#
#
#
#             var marker_bdc3e326a926bc4a19ec0161723f4c4a = L.marker(
#                 [33.462818, 126.910286],
#                 {}
#             ).addTo(map_4feda49ee42007eb14cd04b2cb870302);
#
#
#             var icon_2d0c9e0c7a1f65562cda2f900e70ca4b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bdc3e326a926bc4a19ec0161723f4c4a.setIcon(icon_2d0c9e0c7a1f65562cda2f900e70ca4b);
#
#
#         var popup_b817f3196a5bb1178201ba8a2ba6362d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_de992aebc57a8251c23052e50c272e85 = $(`&lt;div id=&quot;html_de992aebc57a8251c23052e50c272e85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;오조리상동입구&lt;/div&gt;`)[0];
#                 popup_b817f3196a5bb1178201ba8a2ba6362d.setContent(html_de992aebc57a8251c23052e50c272e85);
#
#
#
#         marker_bdc3e326a926bc4a19ec0161723f4c4a.bindPopup(popup_b817f3196a5bb1178201ba8a2ba6362d)
#         ;
#
#
#
#
#             var marker_dc505810daec1496790dc7995a7649aa = L.marker(
#                 [33.4657, 126.908417],
#                 {}
#             ).addTo(map_4feda49ee42007eb14cd04b2cb870302);
#
#
#             var icon_e14a78d20226f7f7b811e4586937ab52 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dc505810daec1496790dc7995a7649aa.setIcon(icon_e14a78d20226f7f7b811e4586937ab52);
#
#
#         var popup_003cc7e7620e09088503afda4f621b43 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da2898191398fb7e66bc2278879ebf12 = $(`&lt;div id=&quot;html_da2898191398fb7e66bc2278879ebf12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;성산고입구삼거리&lt;/div&gt;`)[0];
#                 popup_003cc7e7620e09088503afda4f621b43.setContent(html_da2898191398fb7e66bc2278879ebf12);
#
#
#
#         marker_dc505810daec1496790dc7995a7649aa.bindPopup(popup_003cc7e7620e09088503afda4f621b43)
#         ;
#
#
#
#
#             var marker_990f6b6ebb5789adaa9ff3018f623493 = L.marker(
#                 [33.46885, 126.905883],
#                 {}
#             ).addTo(map_4feda49ee42007eb14cd04b2cb870302);
#
#
#             var icon_92eb4a0a9b487d30a0f957c31a650dcc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;i

# %% [markdown]
# ## 3. 데이터 전처리
# ## Data Cleansing & Pre-Processing

# %%
train.isna().sum()
# Out:
# id                  0
# date                0
# route_id            0
# vh_id               0
# route_nm            0
# now_latitude        0
# now_longitude       0
# now_station         0
# now_arrive_time     0
# distance            0
# next_station        0
# next_latitude       0
# next_longitude      0
# next_arrive_time    0
# dtype: int64

# %%
test.isna().sum()
# Out:
# id                 0
# date               0
# route_id           0
# vh_id              0
# route_nm           0
# now_latitude       0
# now_longitude      0
# now_station        0
# now_arrive_time    0
# distance           0
# next_station       0
# next_latitude      0
# next_longitude     0
# dtype: int64

# %% [markdown]
# 결측값이 없기 때문에...
#
# 데이터를 수치화하는 전처리를 해보겠음.

# %% [markdown]
# ### pd.Series.str.slice()
# - Series 내에 문자열을 일괄적으로 slicing (자르기)

# %%
train.head()
# Out:
#    id        date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0  2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1  2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2  2019-10-15  405136001  7997025    360-1     33.458783     126.557353
# 3   3  2019-10-15  405136001  7997025    360-1     33.479705     126.543811
# 4   4  2019-10-15  405136001  7997025    360-1     33.485662     126.494923
#
#   now_station now_arrive_time  distance     next_station  next_latitude  \
# 0     제주대학교입구             06시     266.0             제대마을      33.457724
# 1        제대마을             06시     333.0            제대아파트      33.458783
# 2       제대아파트             06시     415.0            제주대학교      33.459893
# 3   남국원(아라방면)             06시     578.0  제주여자중고등학교(아라방면)      33.484860
# 4         도호동             07시     374.0              은남동      33.485822
#
#    next_longitude  next_arrive_time
# 0      126.554014                24
# 1      126.557353                36
# 2      126.561624                40
# 3      126.542928                42
# 4      126.490897                64

# %%
train['now_arrive_time']
# Out:
# 0         06시
# 1         06시
# 2         06시
# 3         06시
# 4         07시
#          ...
# 210452    21시
# 210453    21시
# 210454    21시
# 210455    21시
# 210456    21시
# Name: now_arrive_time, Length: 210457, dtype: object

# %% [markdown]
# now_arrive_time 카테고리가 object형 변수임. 즉, 문자열임

# %%
# pd.Series.str.slice()
train['now_arrive_time'].str.slice(stop = -1).astype('int')
# def slice(start=None, stop=None, step=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-846fd93ec052> in <cell line: 2>()
#       1 # pd.Series.str.slice()
# ----> 2 train['now_arrive_time'].str.slice(stop = -1).astype('int')
#       3 # def slice(start=None, stop=None, step=None)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/strings/accessor.py in __init__(self, data)
#     175         from pandas.core.arrays.string_ import StringDtype
#     176
# --> 177         self._inferred_dtype = self._validate(data)
#     178         self._is_categorical = is_categorical_dtype(data.dtype)
#     179         self._is_string = isinstance(data.dtype, StringDtype)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/strings/accessor.py in _validate(data)
#     229
#     230         if inferred_dtype not in allowed_types:
# --> 231             raise AttributeError("Can only use .str accessor with string values!")
#     232         return inferred_dtype
#     233
#
# AttributeError: Can only use .str accessor with string values!

# %%
test['now_arrive_time'] = test['now_arrive_time'].str.slice(stop = -1).astype('int')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210457 entries, 0 to 210456
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                210457 non-null  int64
#  1   date              210457 non-null  object
#  2   route_id          210457 non-null  int64
#  3   vh_id             210457 non-null  int64
#  4   route_nm          210457 non-null  object
#  5   now_latitude      210457 non-null  float64
#  6   now_longitude     210457 non-null  float64
#  7   now_station       210457 non-null  object
#  8   now_arrive_time   210457 non-null  int64
#  9   distance          210457 non-null  float64
#  10  next_station      210457 non-null  object
#  11  next_latitude     210457 non-null  float64
#  12  next_longitude    210457 non-null  float64
#  13  next_arrive_time  210457 non-null  int64
# dtypes: float64(5), int64(5), object(4)
# memory usage: 22.5+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91774 entries, 0 to 91773
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               91774 non-null  int64
#  1   date             91774 non-null  object
#  2   route_id         91774 non-null  int64
#  3   vh_id            91774 non-null  int64
#  4   route_nm         91774 non-null  object
#  5   now_latitude     91774 non-null  float64
#  6   now_longitude    91774 non-null  float64
#  7   now_station      91774 non-null  object
#  8   now_arrive_time  91774 non-null  int64
#  9   distance         91774 non-null  float64
#  10  next_station     91774 non-null  object
#  11  next_latitude    91774 non-null  float64
#  12  next_longitude   91774 non-null  float64
# dtypes: float64(5), int64(4), object(4)
# memory usage: 9.1+ MB

# %% [markdown]
# ## 4. 변수 선택 및 모델 구축
# ## Feature Engineering & Initial Modeling

# %%
train.head()
# Out:
#    id        date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0  2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1  2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2  2019-10-15  405136001  7997025    360-1     33.458783     126.557353
# 3   3  2019-10-15  405136001  7997025    360-1     33.479705     126.543811
# 4   4  2019-10-15  405136001  7997025    360-1     33.485662     126.494923
#
#   now_station  now_arrive_time  distance     next_station  next_latitude  \
# 0     제주대학교입구                6     266.0             제대마을      33.457724
# 1        제대마을                6     333.0            제대아파트      33.458783
# 2       제대아파트                6     415.0            제주대학교      33.459893
# 3   남국원(아라방면)                6     578.0  제주여자중고등학교(아라방면)      33.484860
# 4         도호동                7     374.0              은남동      33.485822
#
#    next_longitude  next_arrive_time
# 0      126.554014                24
# 1      126.557353                36
# 2      126.561624                40
# 3      126.542928                42
# 4      126.490897                64

# %%
features = ['now_latitude', 'now_longitude','now_arrive_time','distance']
target = ['next_arrive_time']

# %%
X_train, X_test, y_train = train[features], test[features], train[target]

# %% [markdown]
# ## 5. 모델 학습 및 검증
# ## Model Tuning & Evaluation

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# %%
model_dict = {
    'linear' : LinearRegression(),
    'rf': RandomForestRegressor(random_state = 0, n_jobs = -1), #n_jobs =/= 사용할 프로세서의 수
    'lgbm': lgb.LGBMRegressor(random_state=0)
}

# %%
model_dict.keys()
# Out:
# dict_keys(['linear', 'rf', 'lgbm'])

# %%
model_dict['linear']   #이렇게 하면 그 모델에 접근할 수 있음
# Out:
# LinearRegression()

# %%
model_result = {}
for key in model_dict.keys():
  print('##### 훈련중 ######')
  model_dict[key].fit(X_train,y_train)
  print('##### 예측중 ######')
  model_result[key] = model_dict[key].predict(X_test)
# Out:
# ##### 훈련중 ######
# ##### 예측중 ######
# ##### 훈련중 ######
# <ipython-input-86-419f0c7185f9>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model_dict[key].fit(X_train,y_train)
# ##### 예측중 ######
# ##### 훈련중 ######
# ##### 예측중 ######

# %%
model_result
# Out:
# {'linear': array([[ 80.75162733],
#         [ 86.59637449],
#         [ 96.03730695],
#         ...,
#         [ 93.13399549],
#         [ 72.93764136],
#         [103.28646517]]),
#  'rf': array([ 35.36650507,  45.12237491, 135.88134374, ..., 126.37972036,
#          31.84467172,  88.46184286]),
#  'lgbm': array([ 42.12400643,  60.24878305, 120.81241189, ..., 105.81387439,
#          30.82952485, 111.66787953])}

# %%
model_result['lgbm']
# Out:
# array([ 42.12400643,  60.24878305, 120.81241189, ..., 105.81387439,
#         30.82952485, 111.66787953])

# %%
lr_submit = submission.copy()
rf_submit = submission.copy()
lgbm_submit = submission.copy()

# %%
lr_submit['next_arrive_time'] = model_result['linear']
rf_submit['next_arrive_time'] = model_result['rf']
lgbm_submit['next_arrive_time'] = model_result['lgbm']

# %%
lr_submit.head()
# Out:
#        id  next_arrive_time
# 0  210457         80.751627
# 1  210458         86.596374
# 2  210459         96.037307
# 3  210460         89.402964
# 4  210461        105.457036

# %%
lr_submit.to_csv('lr_submit.csv', index = False)
rf_submit.to_csv('rf_submit.csv', index = False)
lgbm_submit.to_csv('lgbm_submit.csv', index = False)

# %% [markdown]
# 파라미터 튜닝, 교차검증, 모델 검증, 튜닝 등 안한 가장 베이스 라인의 피팅이었으니
#
# 다른 요소들을 함께 추가해보면 더 좋은 결과를 얻을 수 있음.

# %% [markdown]
# ## 6. 결과 및 결언
# ## Conclusion & Discussion
