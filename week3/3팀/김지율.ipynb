# %% [markdown]
# ## 버스 운행시간 데이터를 활용한 데이터 분석
# - 버스가 다음 정류장에 도착하기 위해서 걸릴 시간을 예측

# %% [markdown]
# ## 1. 라이브러리 및 데이터
# ## Library & Data

# %%
## matplotlib 사용시 한국어 나오게 하는 코드

# !apt -qq -y install fonts-nanum > /dev/null

import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'

font = fm.FontProperties(fname=fontpath, size=9)

# 그래프에 retina display 적용

# %config InlineBackend.figure_format = 'retina'

# Colab 의 한글 폰트 설정

plt.rc('font', family='NanumBarunGothic')
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
import pandas as pd #판다스 패키지 불러오기
import lightgbm as lgb
import folium

# %%
# 데이터 불러오기
train = pd.read_csv('/content/train.csv')
test = pd.read_csv('/content/test.csv')
submission = pd.read_csv('/content/submission_제출양식.csv')

# %% [markdown]
# ## 2. 탐색적 자료분석
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### pd.DataFrame.head()
#  - 데이터 프레임의 위에서 부터 n개 행을 보여주는 함수
#  - n의 기본 값(default 값)은 5

# %%
train.head()
# Out:
#    id        date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0  2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1  2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2  2019-10-15  405136001  7997025    360-1     33.458783     126.557353
# 3   3  2019-10-15  405136001  7997025    360-1     33.479705     126.543811
# 4   4  2019-10-15  405136001  7997025    360-1     33.485662     126.494923
#
#   now_station now_arrive_time  distance     next_station  next_latitude  \
# 0     제주대학교입구             06시     266.0             제대마을      33.457724
# 1        제대마을             06시     333.0            제대아파트      33.458783
# 2       제대아파트             06시     415.0            제주대학교      33.459893
# 3   남국원(아라방면)             06시     578.0  제주여자중고등학교(아라방면)      33.484860
# 4         도호동             07시     374.0              은남동      33.485822
#
#    next_longitude  next_arrive_time
# 0      126.554014                24
# 1      126.557353                36
# 2      126.561624                40
# 3      126.542928                42
# 4      126.490897                64

# %% [markdown]
# + id : 고유 id
# + date : 버스 운행 날짜
# + route_id : 버스 노선 ID
# + vh_id : 버스 id
# + route_nm : 버스 노선 실제 번호
# + now_latitude : 현재 정류소의 위도
# + now_longitude : 현재 정류소의 경도
# + now_station : 현재 정류소 이름
# + now_arrive_time : 현재 정류장에 도착한 시간
# + distance : 현재 정류장에서 다음 정류장까지 실제 이동한 거리
# + next_station : 다음 정류소 이름
# + next_latitude : 다음 정류소의 위도
# + next_longitude : 다음 정류소의 경도
# + next_arrive_time : 다음 정류장에 도착할 때 까지 걸린 시간(단위:초)으로 답안 제출을 위해서 예측해야 되는 값

# %%
test.head()
# Out:
#        id        date   route_id    vh_id route_nm  now_latitude  \
# 0  210457  2019-10-29  405136001  7997025    360-1     33.457724
# 1  210458  2019-10-29  405136001  7997025    360-1     33.458783
# 2  210459  2019-10-29  405136001  7997025    360-1     33.478867
# 3  210460  2019-10-29  405136001  7997025    360-1     33.478850
# 4  210461  2019-10-29  405136001  7997025    360-1     33.480700
#
#    now_longitude  now_station now_arrive_time  distance next_station  \
# 0     126.554014         제대마을             07시     333.0        제대아파트
# 1     126.557353        제대아파트             07시     415.0        제주대학교
# 2     126.483833  한라중학교/부영아파트             08시     417.0      대림2차아파트
# 3     126.488350      대림2차아파트             08시     334.0    연동대림1차아파트
# 4     126.489933    연동대림1차아파트             08시     550.0        케이티앤지
#
#    next_latitude  next_longitude
# 0      33.458783      126.557353
# 1      33.459893      126.561624
# 2      33.478850      126.488350
# 3      33.480700      126.489933
# 4      33.482077      126.485355

# %%
submission.head()
# Out:
#        id  next_arrive_time
# 0  210457                 0
# 1  210458                 0
# 2  210459                 0
# 3  210460                 0
# 4  210461                 0

# %% [markdown]
# ### pd.DataFrame.tail()
#  - 데이터 프레임의 아래에서 부터 n개 행을 보여주는 함수
#  - n의 기본 값(default 값)은 5

# %%
train.tail()
# Out:
#             id        date   route_id    vh_id route_nm  now_latitude  \
# 210452  210452  2019-10-28  405328102  7983486    281-2     33.255783
# 210453  210453  2019-10-28  405328102  7983486    281-2     33.248595
# 210454  210454  2019-10-28  405328102  7983486    281-2     33.251891
# 210455  210455  2019-10-28  405328102  7983486    281-2     33.251084
# 210456  210456  2019-10-28  405328102  7983486    281-2     33.248487
#
#         now_longitude   now_station now_arrive_time  distance  \
# 210452     126.577450          비석거리             21시     528.0
# 210453     126.568527         동문로터리             21시     280.0
# 210454     126.560303  서귀포시 구 버스터미널             21시     114.0
# 210455     126.559551     아랑조을거리 입구             21시     223.0
# 210456     126.511195       대륜동주민센터             21시     189.0
#
#            next_station  next_latitude  next_longitude  next_arrive_time
# 210452            삼아아파트      33.251896      126.574417                96
# 210453      매일올레시장 7번입구      33.249753      126.565959                50
# 210454        아랑조을거리 입구      33.251084      126.559551                16
# 210455            평생학습관      33.249504      126.558068                38
# 210456  서귀포버스터미널(가상정류소)      33.249091      126.509224                24

# %%
print(train['date'].min())
print(train['date'].max())
print(test['date'].min())
print(test['date'].max())
# Out:
# 2019-10-15
# 2019-10-28
# 2019-10-29
# 2019-11-05

# %% [markdown]
# ### pd.DataFrame.shape
#  - 데이터 프레임의 행의 개수와 열의 개수가 저장되어 있는 속성(attribute)

# %%
print(train.shape)
print(test.shape)
print(submission.shape)
# Out:
# (210457, 14)
# (91774, 13)
# (91774, 2)

# %% [markdown]
# ### pd.DataFrame.info()
# - 데이터셋의 column별 정보를 알려주는 함수
# - 비어 있지 않은 값은 (non-null)은 몇개인지?
# - column의 type은 무엇인지?
#  - type의 종류 : int(정수), float(실수), object(문자열), 등등 (date, ...)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210457 entries, 0 to 210456
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                210457 non-null  int64
#  1   date              210457 non-null  object
#  2   route_id          210457 non-null  int64
#  3   vh_id             210457 non-null  int64
#  4   route_nm          210457 non-null  object
#  5   now_latitude      210457 non-null  float64
#  6   now_longitude     210457 non-null  float64
#  7   now_station       210457 non-null  object
#  8   now_arrive_time   210457 non-null  object
#  9   distance          210457 non-null  float64
#  10  next_station      210457 non-null  object
#  11  next_latitude     210457 non-null  float64
#  12  next_longitude    210457 non-null  float64
#  13  next_arrive_time  210457 non-null  int64
# dtypes: float64(5), int64(4), object(5)
# memory usage: 22.5+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91774 entries, 0 to 91773
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               91774 non-null  int64
#  1   date             91774 non-null  object
#  2   route_id         91774 non-null  int64
#  3   vh_id            91774 non-null  int64
#  4   route_nm         91774 non-null  object
#  5   now_latitude     91774 non-null  float64
#  6   now_longitude    91774 non-null  float64
#  7   now_station      91774 non-null  object
#  8   now_arrive_time  91774 non-null  object
#  9   distance         91774 non-null  float64
#  10  next_station     91774 non-null  object
#  11  next_latitude    91774 non-null  float64
#  12  next_longitude   91774 non-null  float64
# dtypes: float64(5), int64(3), object(5)
# memory usage: 9.1+ MB

# %% [markdown]
# ### pd.DataFrame.describe()
# - 숫자형 (int, float) column들의 기술 통계량을 보여주는 함수
#
# - 기술통계량이란?
#  - 해당 column을 대표할 수 있는 통계값들을 의미
#
#
# - 기술통계량 종류
#  - count: 해당 column에서 비어 있지 않은 값의 개수
#  - mean: 평균
#  - std: 표준편차
#  - min: 최솟값 (이상치 포함)
#  - 25% (Q1): 전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 1/4번째 지점에 있는 값
#  - 50% (Q2): 중앙값 (전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 2/4번째 지점에 있는 값)
#  - 75% (Q3): 전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 3/4번째 지점에 있는 값
#  - max: 최댓값 (이상치 포함)
#
#
#
# - 이상치: 울타리 밖에 있는 부분을 이상치라고 정의함
#    - 아래쪽 울타리: $Q_1$ - $1.5 * IQR$
#    - 위쪽 울타리: $Q_3$ + $1.5 * IQR$
#    - $IQR$ = $Q_3 - Q_1$
#
#
# <img src="https://miro.medium.com/max/10125/1*NRlqiZGQdsIyAu0KzP7LaQ.png" width="700" height="500">

# %%
train.describe()
# Out:
#                   id      route_id         vh_id   now_latitude  \
# count  210457.000000  2.104570e+05  2.104570e+05  210457.000000
# mean   105228.000000  4.052491e+08  7.988694e+06      33.434528
# std     60753.847139  9.132404e+04  6.774077e+03       0.102350
# min         0.000000  4.051360e+08  7.983000e+06      33.244382
# 25%     52614.000000  4.051365e+08  7.983093e+06      33.325283
# 50%    105228.000000  4.053201e+08  7.983431e+06      33.484667
# 75%    157842.000000  4.053201e+08  7.997041e+06      33.500197
# max    210456.000000  4.053281e+08  7.997124e+06      33.556167
#
#        now_longitude       distance  next_latitude  next_longitude  \
# count  210457.000000  210457.000000  210457.000000   210457.000000
# mean      126.603451     490.256100      33.434711      126.603687
# std         0.123961     520.563932       0.102224        0.123838
# min       126.473300      97.000000      33.244382      126.473300
# 25%       126.523900     291.000000      33.325283      126.524550
# 50%       126.551050     384.000000      33.484860      126.551050
# 75%       126.650322     542.000000      33.500228      126.650322
# max       126.935188    7461.000000      33.556167      126.935188
#
#        next_arrive_time
# count     210457.000000
# mean          85.380824
# std           85.051170
# min            6.000000
# 25%           44.000000
# 50%           66.000000
# 75%          102.000000
# max         2996.000000

# %% [markdown]
# ### pd.DataFrame.groupby()
#  - 집단에 대한 통계량 확인
#
# <img src="https://s3.amazonaws.com/files.dezyre.com/images/Tutorials/Split+Apply+Combine+Strategy.png" width="700" height="500">

# %%
len(train['now_station'].unique())
# Out:
# 348

# %%
train.groupby('route_id')

# %%
train[['route_id', 'vh_id']].drop_duplicates().groupby('route_id').count()
# drop_duplicates : 중복되는 행을 제거
# DataFrame.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
# subset : 중복값을 검사할 열, keep : 중복제거를 할 때 남길 행, inplace : 원본 변경 여부, ignore_index : 원래의 index 무시 여부부
# Out:
#            vh_id
# route_id
# 405136001     10
# 405136002      5
# 405136007      1
# 405136012      3
# 405136521      6
# 405136522     15
# 405320111      3
# 405320112      5
# 405320113      1
# 405320114      5
# 405320115      1
# 405320116      6
# 405320117      2
# 405320118      1
# 405320121      1
# 405320122      4
# 405320124      3
# 405320126      2
# 405320127      5
# 405328101     11
# 405328102     14

# %%
train[['route_id', 'next_arrive_time']].groupby('route_id').mean()
# Out:
#            next_arrive_time
# route_id
# 405136001         92.063688
# 405136002        108.270852
# 405136007         94.172947
# 405136012        111.322633
# 405136521        114.673939
# 405136522        101.339188
# 405320111         68.901710
# 405320112         67.602392
# 405320113         68.403649
# 405320114         66.634818
# 405320115         71.313237
# 405320116         68.122969
# 405320117         69.239122
# 405320118         67.643471
# 405320121         65.985019
# 405320122         63.955199
# 405320124         66.205659
# 405320126         66.512570
# 405320127         70.824370
# 405328101         87.579634
# 405328102         85.744862

# %% [markdown]
# ## folium
# - python에서 제공하는 지도를 다루는 대표적인 라이브러리
# - folium.Map(location=[위도, 경도], zoom_start=숫자)
# - folium.Marker([위도, 경도], popup = "마우스 클릭시 표기되는 문구", tooltip = "마우스 오버시 표기되는 문구", icon = folium.Icon(color="색상", icon="아이콘 모양").add_to(지도)
# - folium.CircleMarker([위도, 경도], radius = "반경의 범위", color = "선의 색깔", fill_color = "채워질 원의 색깔").add_to(지도)

# %% [markdown]
# ### folium.Map()
#  - location 옵션에 있는 좌표를 중심으로 지도 시각화

# %%
coord = [35.1559361, 129.1384361]
map_osm = folium.Map(location = coord)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20f7af91928bd0a35a8193071b49dc4d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20f7af91928bd0a35a8193071b49dc4d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20f7af91928bd0a35a8193071b49dc4d = L.map(
#                 &quot;map_20f7af91928bd0a35a8193071b49dc4d&quot;,
#                 {
#                     center: [35.1559361, 129.1384361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e1bf1ae510fd5ffd897c92169acb1f8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_20f7af91928bd0a35a8193071b49dc4d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm = folium.Map(location=coord, zoom_start=12)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19fb809de306e4b0099f12072e026444 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19fb809de306e4b0099f12072e026444&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19fb809de306e4b0099f12072e026444 = L.map(
#                 &quot;map_19fb809de306e4b0099f12072e026444&quot;,
#                 {
#                     center: [35.1559361, 129.1384361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1de9bc21396f31776cb5dab46637ea4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_19fb809de306e4b0099f12072e026444);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm = folium.Map(location = coord, tiles = 'Stamen Terrain')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8a1728a7dce8fd3c5c8028878fd4210 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8a1728a7dce8fd3c5c8028878fd4210&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8a1728a7dce8fd3c5c8028878fd4210 = L.map(
#                 &quot;map_a8a1728a7dce8fd3c5c8028878fd4210&quot;,
#                 {
#                     center: [35.1559361, 129.1384361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2dcd16252acb83879c54543a3244f100 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a8a1728a7dce8fd3c5c8028878fd4210);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm = folium.Map(location = coord, tiles = 'Stamen Toner')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad5936e89070b3c187eb1adae8ecbf8c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad5936e89070b3c187eb1adae8ecbf8c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad5936e89070b3c187eb1adae8ecbf8c = L.map(
#                 &quot;map_ad5936e89070b3c187eb1adae8ecbf8c&quot;,
#                 {
#                     center: [35.1559361, 129.1384361],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_942e43a40b1a89af6e006e82244ca8e0 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ad5936e89070b3c187eb1adae8ecbf8c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
coord = [35.2335123, 129.0810047]

map_osm = folium.Map(location=coord, zoom_start=12)

folium.Marker(coord, popup='부산대학교', tooltip = '부산대학교 tooltip').add_to(map_osm) # 마커 생성 뒤 지도에 추가해주는 기능

map_osm.save('index.html')

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a3c84c721b63fded849045364ad5d00 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a3c84c721b63fded849045364ad5d00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a3c84c721b63fded849045364ad5d00 = L.map(
#                 &quot;map_4a3c84c721b63fded849045364ad5d00&quot;,
#                 {
#                     center: [35.2335123, 129.0810047],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf5a14731ea2737b98b5b5a8a4eac1e7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4a3c84c721b63fded849045364ad5d00);
#
#
#             var marker_84e1e075c976da0074b1339d2adf2a18 = L.marker(
#                 [35.2335123, 129.0810047],
#                 {}
#             ).addTo(map_4a3c84c721b63fded849045364ad5d00);
#
#
#         var popup_a27307d9e9ff24ff833bdf1b43ce350e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_522752945a480b14270b1512e781dbc0 = $(`&lt;div id=&quot;html_522752945a480b14270b1512e781dbc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;부산대학교&lt;/div&gt;`)[0];
#                 popup_a27307d9e9ff24ff833bdf1b43ce350e.setContent(html_522752945a480b14270b1512e781dbc0);
#
#
#
#         marker_84e1e075c976da0074b1339d2adf2a18.bindPopup(popup_a27307d9e9ff24ff833bdf1b43ce350e)
#         ;
#
#
#
#
#             marker_84e1e075c976da0074b1339d2adf2a18.bindTooltip(
#                 `&lt;div&gt;
#                      부산대학교 tooltip
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# default images: https://getbootstrap.com/docs/3.3/components/
#
# - 검색 기능이 없다
#
# fontawesome:https://fontawesome.com/icons?d=gallery
#
# - 해당링크의 무료인것만 쓸 수 있음

# %%
map_osm = folium.Map(location=coord, zoom_start=12)
folium.Marker(coord, popup='부산대학교', icon=folium.Icon(icon='home')).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b25fd185679a370228af4d250a62235 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b25fd185679a370228af4d250a62235&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b25fd185679a370228af4d250a62235 = L.map(
#                 &quot;map_8b25fd185679a370228af4d250a62235&quot;,
#                 {
#                     center: [35.2335123, 129.0810047],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f428fbbd792eba2f3a03a1947e2a7e3f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8b25fd185679a370228af4d250a62235);
#
#
#             var marker_e578659be47bccb225162fa81f5a390a = L.marker(
#                 [35.2335123, 129.0810047],
#                 {}
#             ).addTo(map_8b25fd185679a370228af4d250a62235);
#
#
#             var icon_ba9d2205b4cc436781efaa1a0ecb8e0e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e578659be47bccb225162fa81f5a390a.setIcon(icon_ba9d2205b4cc436781efaa1a0ecb8e0e);
#
#
#         var popup_c3277f925de7ee60ef35ec9efdd3314d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a26a81c7b7e72200670a0fbed0c50f7 = $(`&lt;div id=&quot;html_0a26a81c7b7e72200670a0fbed0c50f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;부산대학교&lt;/div&gt;`)[0];
#                 popup_c3277f925de7ee60ef35ec9efdd3314d.setContent(html_0a26a81c7b7e72200670a0fbed0c50f7);
#
#
#
#         marker_e578659be47bccb225162fa81f5a390a.bindPopup(popup_c3277f925de7ee60ef35ec9efdd3314d)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm = folium.Map(location=[37.541, 126.986], zoom_start=11)
folium.Marker([37.566345, 126.977893], popup='서울특별시청', icon=folium.Icon(color='red',icon='info-sign')).add_to(map_osm)
folium.Circle([37.4600, 126.9519], tooltip='서울대학교', radius=3000, color="green").add_to(map_osm)
folium.CircleMarker([37.5662, 126.9386], radius=10, popup='연세대학교',color="black", fill_color="crimson").add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e752db5cf63e83163415cdc010d44c41 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e752db5cf63e83163415cdc010d44c41&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e752db5cf63e83163415cdc010d44c41 = L.map(
#                 &quot;map_e752db5cf63e83163415cdc010d44c41&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a14c441d8718661a71c371a79752472 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e752db5cf63e83163415cdc010d44c41);
#
#
#             var marker_33cd3164b69e8744de34cb7722d99e92 = L.marker(
#                 [37.566345, 126.977893],
#                 {}
#             ).addTo(map_e752db5cf63e83163415cdc010d44c41);
#
#
#             var icon_b728221944d8c61840a015bedb0a4c06 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_33cd3164b69e8744de34cb7722d99e92.setIcon(icon_b728221944d8c61840a015bedb0a4c06);
#
#
#         var popup_0aa17a9f48ac20c3a66925a712c6e36f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3df142f2c999408cb79369830bbe43a8 = $(`&lt;div id=&quot;html_3df142f2c999408cb79369830bbe43a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시청&lt;/div&gt;`)[0];
#                 popup_0aa17a9f48ac20c3a66925a712c6e36f.setContent(html_3df142f2c999408cb79369830bbe43a8);
#
#
#
#         marker_33cd3164b69e8744de34cb7722d99e92.bindPopup(popup_0aa17a9f48ac20c3a66925a712c6e36f)
#         ;
#
#
#
#
#             var circle_372e8ca632ad6e63e14feb3f646f586f = L.circle(
#                 [37.46, 126.9519],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e752db5cf63e83163415cdc010d44c41);
#
#
#             circle_372e8ca632ad6e63e14feb3f646f586f.bindTooltip(
#                 `&lt;div&gt;
#                      서울대학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_073d1941e65aed8cd16395aa4f7e2638 = L.circleMarker(
#                 [37.5662, 126.9386],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e752db5cf63e83163415cdc010d44c41);
#
#
#         var popup_559e7b9be8bf9feae1270e55427473c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7985a9367b59ac34981200eb1626d865 = $(`&lt;div id=&quot;html_7985a9367b59ac34981200eb1626d865&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;연세대학교&lt;/div&gt;`)[0];
#                 popup_559e7b9be8bf9feae1270e55427473c1.setContent(html_7985a9367b59ac34981200eb1626d865);
#
#
#
#         circle_marker_073d1941e65aed8cd16395aa4f7e2638.bindPopup(popup_559e7b9be8bf9feae1270e55427473c1)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm = folium.Map(location=[37.541, 126.986], zoom_start=11)
folium.RegularPolygonMarker([37.566345, 126.977893], popup='서울특별시청', fill_color='red',color='red', number_of_sides=3, radius=30, fill_opacity=0.2).add_to(map_osm)
folium.RegularPolygonMarker([37.4600, 126.9519], popup='서울대학교', fill_color='green',color='green', number_of_sides=4, radius=10, fill_opacity=0.2).add_to(map_osm)
folium.RegularPolygonMarker([37.5662, 126.9386], popup='연세대학교',fill_color='blue',color='blue', number_of_sides=6, radius=10).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8761629169c200fdfdb2757538287bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8761629169c200fdfdb2757538287bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8761629169c200fdfdb2757538287bc = L.map(
#                 &quot;map_d8761629169c200fdfdb2757538287bc&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c614342653bbeff865e73268b93fb0bf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d8761629169c200fdfdb2757538287bc);
#
#
#             var regular_polygon_marker_d7000a9e6c758dc2d8e78b8c60add318 = new L.RegularPolygonMarker(
#                 [37.566345, 126.977893],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d8761629169c200fdfdb2757538287bc);
#
#
#         var popup_c35ca7071d571e3c0fbc394ecb22db0f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_755157def0f2634ce0dda11688a0ccf2 = $(`&lt;div id=&quot;html_755157def0f2634ce0dda11688a0ccf2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시청&lt;/div&gt;`)[0];
#                 popup_c35ca7071d571e3c0fbc394ecb22db0f.setContent(html_755157def0f2634ce0dda11688a0ccf2);
#
#
#
#         regular_polygon_marker_d7000a9e6c758dc2d8e78b8c60add318.bindPopup(popup_c35ca7071d571e3c0fbc394ecb22db0f)
#         ;
#
#
#
#
#             var regular_polygon_marker_4e48f262e2bf68c5b7bcddc60014cb40 = new L.RegularPolygonMarker(
#                 [37.46, 126.9519],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d8761629169c200fdfdb2757538287bc);
#
#
#         var popup_0608852c09efe977df2863131352c48a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e560beed7e39a4436762bba4f45100d = $(`&lt;div id=&quot;html_0e560beed7e39a4436762bba4f45100d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울대학교&lt;/div&gt;`)[0];
#                 popup_0608852c09efe977df2863131352c48a.setContent(html_0e560beed7e39a4436762bba4f45100d);
#
#
#
#         regular_polygon_marker_4e48f262e2bf68c5b7bcddc60014cb40.bindPopup(popup_0608852c09efe977df2863131352c48a)
#         ;
#
#
#
#
#             var regular_polygon_marker_5613fcc54b58786bc17eb2d672a1545c = new L.RegularPolygonMarker(
#                 [37.5662, 126.9386],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 6, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d8761629169c200fdfdb2757538287bc);
#
#
#         var popup_c62a22140e4ce7c81a55a5340f838605 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_03082d18689db817921bc48edf11f642 = $(`&lt;div id=&quot;html_03082d18689db817921bc48edf11f642&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;연세대학교&lt;/div&gt;`)[0];
#                 popup_c62a22140e4ce7c81a55a5340f838605.setContent(html_03082d18689db817921bc48edf11f642);
#
#
#
#         regular_polygon_marker_5613fcc54b58786bc17eb2d672a1545c.bindPopup(popup_c62a2

# %%
cd = train.loc[0, 'now_latitude':'now_longitude'].tolist()
map_osm = folium.Map(location=cd, zoom_start=12)
folium.Marker(cd, icon=folium.Icon(icon='nome')).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b6041b37d46a8d7d16abb062f58c0de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b6041b37d46a8d7d16abb062f58c0de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b6041b37d46a8d7d16abb062f58c0de = L.map(
#                 &quot;map_2b6041b37d46a8d7d16abb062f58c0de&quot;,
#                 {
#                     center: [33.456267, 126.55175],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_feec95d1c9129f9189c34699caad213e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2b6041b37d46a8d7d16abb062f58c0de);
#
#
#             var marker_2ebe800ea6fa64a47c5e55be1a855ab2 = L.marker(
#                 [33.456267, 126.55175],
#                 {}
#             ).addTo(map_2b6041b37d46a8d7d16abb062f58c0de);
#
#
#             var icon_53ec61c832ac4d015f0b360ac7283fc7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;nome&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2ebe800ea6fa64a47c5e55be1a855ab2.setIcon(icon_53ec61c832ac4d015f0b360ac7283fc7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
train
# Out:
#             id        date   route_id    vh_id route_nm  now_latitude  \
# 0            0  2019-10-15  405136001  7997025    360-1     33.456267
# 1            1  2019-10-15  405136001  7997025    360-1     33.457724
# 2            2  2019-10-15  405136001  7997025    360-1     33.458783
# 3            3  2019-10-15  405136001  7997025    360-1     33.479705
# 4            4  2019-10-15  405136001  7997025    360-1     33.485662
# ...        ...         ...        ...      ...      ...           ...
# 210452  210452  2019-10-28  405328102  7983486    281-2     33.255783
# 210453  210453  2019-10-28  405328102  7983486    281-2     33.248595
# 210454  210454  2019-10-28  405328102  7983486    281-2     33.251891
# 210455  210455  2019-10-28  405328102  7983486    281-2     33.251084
# 210456  210456  2019-10-28  405328102  7983486    281-2     33.248487
#
#         now_longitude   now_station now_arrive_time  distance  \
# 0          126.551750       제주대학교입구             06시     266.0
# 1          126.554014          제대마을             06시     333.0
# 2          126.557353         제대아파트             06시     415.0
# 3          126.543811     남국원(아라방면)             06시     578.0
# 4          126.494923           도호동             07시     374.0
# ...               ...           ...             ...       ...
# 210452     126.577450          비석거리             21시     528.0
# 210453     126.568527         동문로터리             21시     280.0
# 210454     126.560303  서귀포시 구 버스터미널             21시     114.0
# 210455     126.559551     아랑조을거리 입구             21시     223.0
# 210456     126.511195       대륜동주민센터             21시     189.0
#
#            next_station  next_latitude  next_longitude  next_arrive_time
# 0                  제대마을      33.457724      126.554014                24
# 1                 제대아파트      33.458783      126.557353                36
# 2                 제주대학교      33.459893      126.561624                40
# 3       제주여자중고등학교(아라방면)      33.484860      126.542928                42
# 4                   은남동      33.485822      126.490897                64
# ...                 ...            ...             ...               ...
# 210452            삼아아파트      33.251896      126.574417                96
# 210453      매일올레시장 7번입구      33.249753      126.565959                50
# 210454        아랑조을거리 입구      33.251084      126.559551                16
# 210455            평생학습관      33.249504      126.558068                38
# 210456  서귀포버스터미널(가상정류소)      33.249091      126.509224                24
#
# [210457 rows x 14 columns]

# %%
map_data = train[['route_id','now_latitude','now_longitude','now_station']]
map_bus_route = map_data[map_data['route_id'] == 405320122].drop_duplicates("now_station")


map_osm = folium.Map(location=[33.4134, 126.5190], zoom_start = 10.5)


for item in map_bus_route.index:
    lat = map_bus_route.loc[item,'now_latitude']
    long = map_bus_route.loc[item,'now_longitude']
    
    folium.Marker([lat,long], popup = map_bus_route.loc[item,'now_station'],
                      icon = folium.Icon(color = 'red', icon = 'info-sign')
                      ).add_to(map_osm)

map_osm.save('index.html')

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1001a7f735fef18b90a4f4ff276723e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1001a7f735fef18b90a4f4ff276723e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1001a7f735fef18b90a4f4ff276723e7 = L.map(
#                 &quot;map_1001a7f735fef18b90a4f4ff276723e7&quot;,
#                 {
#                     center: [33.4134, 126.519],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18a064fa7b7181ce0a75d4d8178c197a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1001a7f735fef18b90a4f4ff276723e7);
#
#
#             var marker_30bf4eff42c519763769424844db2b69 = L.marker(
#                 [33.449467, 126.91505],
#                 {}
#             ).addTo(map_1001a7f735fef18b90a4f4ff276723e7);
#
#
#             var icon_e1f456d2206271f9a1886b17d7c28233 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_30bf4eff42c519763769424844db2b69.setIcon(icon_e1f456d2206271f9a1886b17d7c28233);
#
#
#         var popup_2a924f6648956dc57c433c08145b3aab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34f7c285faa0af71439449ebc8e3af9a = $(`&lt;div id=&quot;html_34f7c285faa0af71439449ebc8e3af9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;고성리제주은행&lt;/div&gt;`)[0];
#                 popup_2a924f6648956dc57c433c08145b3aab.setContent(html_34f7c285faa0af71439449ebc8e3af9a);
#
#
#
#         marker_30bf4eff42c519763769424844db2b69.bindPopup(popup_2a924f6648956dc57c433c08145b3aab)
#         ;
#
#
#
#
#             var marker_03b225bf974c713bbf0825da96637a82 = L.marker(
#                 [33.462818, 126.910286],
#                 {}
#             ).addTo(map_1001a7f735fef18b90a4f4ff276723e7);
#
#
#             var icon_d9c1e81d317b8703110dcccf33cf31de = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_03b225bf974c713bbf0825da96637a82.setIcon(icon_d9c1e81d317b8703110dcccf33cf31de);
#
#
#         var popup_f462c7f046ef454a735ca3aeaa252794 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2785f1aa74ebab77c279495931a7fbd6 = $(`&lt;div id=&quot;html_2785f1aa74ebab77c279495931a7fbd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;오조리상동입구&lt;/div&gt;`)[0];
#                 popup_f462c7f046ef454a735ca3aeaa252794.setContent(html_2785f1aa74ebab77c279495931a7fbd6);
#
#
#
#         marker_03b225bf974c713bbf0825da96637a82.bindPopup(popup_f462c7f046ef454a735ca3aeaa252794)
#         ;
#
#
#
#
#             var marker_c9c84aba117df91cc8ef97ac48d4fc83 = L.marker(
#                 [33.4657, 126.908417],
#                 {}
#             ).addTo(map_1001a7f735fef18b90a4f4ff276723e7);
#
#
#             var icon_1b4116949b7930dc8eb6889693741b0b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c9c84aba117df91cc8ef97ac48d4fc83.setIcon(icon_1b4116949b7930dc8eb6889693741b0b);
#
#
#         var popup_e0039118a16789276b8903962c701ff4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aeccbe8295ec951c17dbcbe720efd305 = $(`&lt;div id=&quot;html_aeccbe8295ec951c17dbcbe720efd305&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;성산고입구삼거리&lt;/div&gt;`)[0];
#                 popup_e0039118a16789276b8903962c701ff4.setContent(html_aeccbe8295ec951c17dbcbe720efd305);
#
#
#
#         marker_c9c84aba117df91cc8ef97ac48d4fc83.bindPopup(popup_e0039118a16789276b8903962c701ff4)
#         ;
#
#
#
#
#             var marker_09c563e308a044517977c18f45aedf5e = L.marker(
#                 [33.46885, 126.905883],
#                 {}
#             ).addTo(map_1001a7f735fef18b90a4f4ff276723e7);
#
#
#             var icon_321342e1ada8be2ccafc09189d09faee = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;i

# %% [markdown]
# ## 3. 데이터 전처리
# ## Data Cleansing & Pre-Processing

# %% [markdown]
# ### pd.Series.str.slice()
# - Series 내에 문자열을 일괄적으로 slicing (자르기)

# %%
train['now_arrive_time'] = train['now_arrive_time'].str.slice(stop = -1).astype('int')
# astype : 데이터프레임의 타입 변경경

# %%
train.head()
# Out:
#    id        date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0  2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1  2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2  2019-10-15  405136001  7997025    360-1     33.458783     126.557353
# 3   3  2019-10-15  405136001  7997025    360-1     33.479705     126.543811
# 4   4  2019-10-15  405136001  7997025    360-1     33.485662     126.494923
#
#   now_station  now_arrive_time  distance     next_station  next_latitude  \
# 0     제주대학교입구                6     266.0             제대마을      33.457724
# 1        제대마을                6     333.0            제대아파트      33.458783
# 2       제대아파트                6     415.0            제주대학교      33.459893
# 3   남국원(아라방면)                6     578.0  제주여자중고등학교(아라방면)      33.484860
# 4         도호동                7     374.0              은남동      33.485822
#
#    next_longitude  next_arrive_time
# 0      126.554014                24
# 1      126.557353                36
# 2      126.561624                40
# 3      126.542928                42
# 4      126.490897                64

# %%
test['now_arrive_time'] = test['now_arrive_time'].str.slice(stop = -1).astype('int')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91774 entries, 0 to 91773
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               91774 non-null  int64
#  1   date             91774 non-null  object
#  2   route_id         91774 non-null  int64
#  3   vh_id            91774 non-null  int64
#  4   route_nm         91774 non-null  object
#  5   now_latitude     91774 non-null  float64
#  6   now_longitude    91774 non-null  float64
#  7   now_station      91774 non-null  object
#  8   now_arrive_time  91774 non-null  int64
#  9   distance         91774 non-null  float64
#  10  next_station     91774 non-null  object
#  11  next_latitude    91774 non-null  float64
#  12  next_longitude   91774 non-null  float64
# dtypes: float64(5), int64(4), object(4)
# memory usage: 9.1+ MB

# %% [markdown]
# ## 4. 변수 선택 및 모델 구축
# ## Feature Engineering & Initial Modeling

# %%
train.head()
# Out:
#    id        date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0  2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1  2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2  2019-10-15  405136001  7997025    360-1     33.458783     126.557353
# 3   3  2019-10-15  405136001  7997025    360-1     33.479705     126.543811
# 4   4  2019-10-15  405136001  7997025    360-1     33.485662     126.494923
#
#   now_station  now_arrive_time  distance     next_station  next_latitude  \
# 0     제주대학교입구                6     266.0             제대마을      33.457724
# 1        제대마을                6     333.0            제대아파트      33.458783
# 2       제대아파트                6     415.0            제주대학교      33.459893
# 3   남국원(아라방면)                6     578.0  제주여자중고등학교(아라방면)      33.484860
# 4         도호동                7     374.0              은남동      33.485822
#
#    next_longitude  next_arrive_time
# 0      126.554014                24
# 1      126.557353                36
# 2      126.561624                40
# 3      126.542928                42
# 4      126.490897                64

# %%
features = ['now_latitude', 'now_longitude', 'now_arrive_time', 'distance']
target = ['next_arrive_time']

# %%
X_train, X_test, y_train = train[features], test[features], train[target]

# %% [markdown]
# ## 5. 모델 학습 및 검증
# ## Model Tuning & Evaluation

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# %%
model_dict = {
    'linear':LinearRegression(),
    'rf':RandomForestRegressor(random_state=0, n_jobs=-1),
    'lgbm':lgb.LGBMRegressor(random_state=0)
}

# %%
model_dict.keys()
# Out:
# dict_keys(['linear', 'rf', 'lgbm'])

# %%
model_dict['rf']
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=0)

# %%
model_result = {}

for key in model_dict.keys():
  print('#### 훈련 중 ####')
  model_dict[key].fit(X_train, y_train)
  print('#### 예측 중 ####')
  model_result[key] = model_dict[key].predict(X_test)
# Out:
# #### 훈련 중 ####
# #### 예측 중 ####
# #### 훈련 중 ####
# <ipython-input-48-c0009cf2472e>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model_dict[key].fit(X_train, y_train)
# #### 예측 중 ####
# #### 훈련 중 ####
# #### 예측 중 ####

# %%
model_result['rf']
# Out:
# array([ 35.36650507,  45.12237491, 135.88134374, ..., 126.37972036,
#         31.84467172,  88.46184286])

# %%
lr_submit = submission.copy()
rf_submit = submission.copy()
lgbm_submit = submission.copy()

# %%
lr_submit['next_arrive_time'] = model_result['linear']
rf_submit['next_arrive_time'] = model_result['rf']
lgbm_submit['next_arrive_time'] = model_result['lgbm']

# %%
lgbm_submit.head()
# Out:
#        id  next_arrive_time
# 0  210457         42.124006
# 1  210458         60.248783
# 2  210459        120.812412
# 3  210460         61.146493
# 4  210461        150.454103

# %%
lr_submit.to_csv('lr_submit.csv', index = False)
rf_submit.to_csv('rf_submit.csv', index = False)
lgbm_submit.to_csv('lgbm_submit.csv', index = False)

# %% [markdown]
# ## 6. 결과 및 결언
# ## Conclusion & Discussion
