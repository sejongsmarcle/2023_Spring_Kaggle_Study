# %% [markdown]
# # <center> 🛳️ TITANIC 🛳️ </center>

# %% [markdown]
# ## 1. Dataset 확인

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 스타일링
plt.style.use('seaborn')
# 폰트
sns.set(font_scale=2.5)
# 데이터 시각화 패키지 _ missingno, plotly
import missingno as msno
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#경고 무시
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df_train = pd.read_csv('../input/titanic/train.csv')
df_test = pd.read_csv('../input/titanic/test.csv')

# %% [markdown]
# ### 1-1. Data check
# 1. survival : 생존여부
# 2. Pclass : 티켓의 클래스 (1,2,3)
# 3. sex : 성별
# 4. Age: 나이
# 5. sibSp : 함께 탑승한 형제와 배우자의 수
# 6. parch : 함께 탑승한 부모, 아이의 수
# 7. ticket : 티켓 번호
# 8. fare : 탑승료
# 9. cabin : 객실 번호
# 10. embared : 탑승 항구

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### 1-2. Null data check

# %% [markdown]
# (1) Train의 NULL값 확인
# > Cabin(객실번호) : 80% / 오류가장 많음
#
# > Age(나이) : 20%
#
# (2) MSNO : data의 존재 시각화

# %%
for col in df_train.columns:
    msg = 'column: {:>10}\t Percent of NaN value: {:.2f}%'.format(col, 100 * (df_train[col].isnull().sum() / df_train[col].shape[0]))
    print(msg)
# Out:
# column: PassengerId	 Percent of NaN value: 0.00%
# column:   Survived	 Percent of NaN value: 0.00%
# column:     Pclass	 Percent of NaN value: 0.00%
# column:       Name	 Percent of NaN value: 0.00%
# column:        Sex	 Percent of NaN value: 0.00%
# column:        Age	 Percent of NaN value: 19.87%
# column:      SibSp	 Percent of NaN value: 0.00%
# column:      Parch	 Percent of NaN value: 0.00%
# column:     Ticket	 Percent of NaN value: 0.00%
# column:       Fare	 Percent of NaN value: 0.00%
# column:      Cabin	 Percent of NaN value: 77.10%
# column:   Embarked	 Percent of NaN value: 0.22%

# %%
msno.bar(df=df_train.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2))
# Out:
# <Axes: >

# %% [markdown]
# (1) Test NULL값 확인
# > Cabin(객실번호) : 80% / 오류가장 많음
#
# > Age(나이) : 20%
#
# (2) MSNO : data의 존재 시각화

# %%
for col in df_test.columns:
    msg = 'column: {:>10}\t Percent of NaN value: {:.2f}%'.format(col, 100 * (df_test[col].isnull().sum() / df_test[col].shape[0]))
    print(msg)
# Out:
# column: PassengerId	 Percent of NaN value: 0.00%
# column:     Pclass	 Percent of NaN value: 0.00%
# column:       Name	 Percent of NaN value: 0.00%
# column:        Sex	 Percent of NaN value: 0.00%
# column:        Age	 Percent of NaN value: 20.57%
# column:      SibSp	 Percent of NaN value: 0.00%
# column:      Parch	 Percent of NaN value: 0.00%
# column:     Ticket	 Percent of NaN value: 0.00%
# column:       Fare	 Percent of NaN value: 0.24%
# column:      Cabin	 Percent of NaN value: 78.23%
# column:   Embarked	 Percent of NaN value: 0.00%

# %%
msno.bar(df=df_test.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2))
# Out:
# <Axes: >

# %% [markdown]
# ### 1-3. 결과 확인
# > 38.4% 생존

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

df_train['Survived'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Pie plot - Survived')


plt.show()

# %% [markdown]
# ## 2. EDA / 데이터 별 생존률 확인
#  : 데이터 분석
#
#  '시각화 라이브러리'
#  1. matplotlib :
#  2. seaborn :
#  3. plotly :

# %% [markdown]
# ### (1) Pclass (티켓등급)
#
# (1) 세기 / (2) 합계 / (3) 시각화 / (4) 도표
#
#
# **→ 등급이 높을수록, 생존률이 높다**

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_831ee_row0_col0, #T_831ee_row1_col1, #T_831ee_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_831ee_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_831ee_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_831ee_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_831ee_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_831ee_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_831ee_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_831ee_row3_col0, #T_831ee_row3_col1, #T_831ee_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_831ee">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_831ee_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_831ee_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_831ee_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_831ee_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_831ee_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_831ee_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_831ee_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_831ee_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_831ee_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_831ee_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_831ee_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_831ee_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_831ee_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_831ee_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_831ee_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_831ee_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_831ee_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_831ee_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_831ee_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar()
# Out:
# <Axes: xlabel='Pclass'>

# %% [markdown]
# ### (2) Sex (성별)
#
# (1) 평균 / (3) 시각화 / (4) 도표
#
#
# **→ 여성일수록, 생존률이 높다**

# %%
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
pd.crosstab(df_train['Sex'], df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_457bc_row0_col0, #T_457bc_row0_col2, #T_457bc_row1_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_457bc_row0_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_457bc_row1_col0 {
#   background-color: #2c9666;
#   color: #f1f1f1;
# }
# #T_457bc_row1_col2 {
#   background-color: #8bc566;
#   color: #000000;
# }
# #T_457bc_row2_col0, #T_457bc_row2_col1, #T_457bc_row2_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_457bc">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_457bc_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_457bc_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_457bc_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_457bc_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_457bc_row0_col0" class="data row0 col0" >81</td>
#       <td id="T_457bc_row0_col1" class="data row0 col1" >233</td>
#       <td id="T_457bc_row0_col2" class="data row0 col2" >314</td>
#     </tr>
#     <tr>
#       <th id="T_457bc_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_457bc_row1_col0" class="data row1 col0" >468</td>
#       <td id="T_457bc_row1_col1" class="data row1 col1" >109</td>
#       <td id="T_457bc_row1_col2" class="data row1 col2" >577</td>
#     </tr>
#     <tr>
#       <th id="T_457bc_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_457bc_row2_col0" class="data row2 col0" >549</td>
#       <td id="T_457bc_row2_col1" class="data row2 col1" >342</td>
#       <td id="T_457bc_row2_col2" class="data row2 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
# Out:
# Text(0.5, 1.0, 'Survived vs Sex')

# %% [markdown]
# ### (3) Sex +Pclass
#
# **→ 클래스와 상관 없이, 여성일수록 생존률이 높다**

# %% [markdown]
# ### (4) AGE (나이)
#
# (1) 나이 분포 / (2) 히스토그램
#
# **→ 어릴 수록, 생존률이 높다**
#
#
# **→ but, class가 높을 수록 연령이 높아진다**

# %%
print('제일 나이 많은 탑승객 : {:.1f} Years'.format(df_train['Age'].max()))
print('제일 어린 탑승객 : {:.1f} Years'.format(df_train['Age'].min()))
print('탑승객 평균 나이 : {:.1f} Years'.format(df_train['Age'].mean()))
# Out:
# 제일 나이 많은 탑승객 : 80.0 Years
# 제일 어린 탑승객 : 0.4 Years
# 탑승객 평균 나이 : 29.7 Years

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(df_train[df_train['Survived'] == 1]['Age'], ax=ax)
sns.kdeplot(df_train[df_train['Survived'] == 0]['Age'], ax=ax)
plt.legend(['Survived == 1', 'Survived == 0'])
plt.show()

# %%
# Age distribution withing classes
plt.figure(figsize=(8, 6))
df_train['Age'][df_train['Pclass'] == 1].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 2].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 3].plot(kind='kde')

plt.xlabel('Age')
plt.title('Age Distribution within classes')
plt.legend(['1st Class', '2nd Class', '3rd Class'])

# %% [markdown]
# ### (5) Sex + Pclass + Age
#
# **→ 여성, 아이가 우선순위**

# %% [markdown]
# ### (6) Embarked (탑승 항구)
#
#  (1) 시각화
#
# **→ C / Q / S 순으로 생존률 높음**

# %%
f, ax = plt.subplots(1, 1, figsize=(7, 7))
df_train[['Embarked', 'Survived']].groupby(['Embarked'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax)
# Out:
# <Axes: xlabel='Embarked'>

# %% [markdown]
# ### (7) Fmaily - Sibsp,parch (형제 자매, 부모)
#
# (1) 최대값, 최소값

# %%
df_train['FamilySize'] = df_train['SibSp'] + df_train['Parch'] + 1 # 자신을 포함해야하니 1을 더합니다
df_test['FamilySize'] = df_test['SibSp'] + df_test['Parch'] + 1 # 자신을 포함해야하니 1을 더합니다

print("Maximum size of Family: ", df_train['FamilySize'].max())
print("Minimum size of Family: ", df_train['FamilySize'].min())
# Out:
# Maximum size of Family:  11
# Minimum size of Family:  1

# %% [markdown]
# ### (8) Fare (탑승요금)
#
#  (1) 히스토그램

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
g = sns.distplot(df_train['Fare'], color='b', label='Skewness : {:.2f}'.format(df_train['Fare'].skew()), ax=ax)
g = g.legend(loc='best')

# %% [markdown]
# ### (9) Cabin (객실번호)
#  - Nan 값이 가장 많은 객체
#  -> So, 모델 포함 안함

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      0         A/5 21171   7.2500   NaN        S           2
# 1      0          PC 17599  71.2833   C85        C           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1
# 3      0            113803  53.1000  C123        S           2
# 4      0            373450   8.0500   NaN        S           1

# %% [markdown]
# ### (10) Ticket(티켓)

# %%
df_train['Ticket'].value_counts()
# Out:
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: Ticket, Length: 681, dtype: int64

# %% [markdown]
# # 8주차

# %%
# FamilySize 가족 수 = Sibsp(형제)+Parch(부모)+1(자신)
df_train['FamilySize'] = df_train['SibSp'] + df_train['Parch'] + 1 
df_test['FamilySize'] = df_test['SibSp'] + df_test['Parch'] + 1 

df_test.loc[df_test.Fare.isnull(), 'Fare'] = df_test['Fare'].mean()

df_train['Fare'] = df_train['Fare'].map(lambda i: np.log(i) if i > 0 else 0)
df_test['Fare'] = df_test['Fare'].map(lambda i: np.log(i) if i > 0 else 0)

# %% [markdown]
# ## 3-1. Feature Engineering  _  ① null data 채우기

# %% [markdown]
# ### (1) AGE (나이)
# ---
# 1) 이름에는 Miss, Mrs와 같은 수식이 붙음
#
# 2) crosstab을 이용해서, 이름-성별 간의 사용현황을 확인
#
# 3) 이러한 것을 Master, Miss, Mr, Mrs, Other로 각각 명명해줌
#
# **→ 여성의 생존률이 높다는 것을 확인할 수 있음**

# %%
df_train['Initial']= df_train.Name.str.extract('([A-Za-z]+)\.')
df_test['Initial']= df_test.Name.str.extract('([A-Za-z]+)\.') 

pd.crosstab(df_train['Initial'], df_train['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_fe9ca_row0_col0, #T_fe9ca_row0_col1, #T_fe9ca_row0_col3, #T_fe9ca_row0_col4, #T_fe9ca_row0_col5, #T_fe9ca_row0_col7, #T_fe9ca_row0_col8, #T_fe9ca_row0_col12, #T_fe9ca_row0_col15, #T_fe9ca_row0_col16, #T_fe9ca_row1_col2, #T_fe9ca_row1_col6, #T_fe9ca_row1_col9, #T_fe9ca_row1_col10, #T_fe9ca_row1_col11, #T_fe9ca_row1_col13, #T_fe9ca_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_fe9ca_row0_col2, #T_fe9ca_row0_col6, #T_fe9ca_row0_col9, #T_fe9ca_row0_col10, #T_fe9ca_row0_col11, #T_fe9ca_row0_col13, #T_fe9ca_row0_col14, #T_fe9ca_row1_col0, #T_fe9ca_row1_col1, #T_fe9ca_row1_col3, #T_fe9ca_row1_col4, #T_fe9ca_row1_col5, #T_fe9ca_row1_col7, #T_fe9ca_row1_col8, #T_fe9ca_row1_col12, #T_fe9ca_row1_col15, #T_fe9ca_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fe9ca">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_fe9ca_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_fe9ca_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_fe9ca_level0_col2" class="col_heading level0 col2" >Countess</th>
#       <th id="T_fe9ca_level0_col3" class="col_heading level0 col3" >Don</th>
#       <th id="T_fe9ca_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_fe9ca_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_fe9ca_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_fe9ca_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_fe9ca_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_fe9ca_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_fe9ca_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_fe9ca_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_fe9ca_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_fe9ca_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_fe9ca_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_fe9ca_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_fe9ca_level0_col16" class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe9ca_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_fe9ca_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_fe9ca_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_fe9ca_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_fe9ca_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fe9ca_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_fe9ca_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_fe9ca_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_fe9ca_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_fe9ca_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_fe9ca_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_fe9ca_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_fe9ca_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_fe9ca_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_fe9ca_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_fe9ca_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_fe9ca_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_fe9ca_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fe9ca_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_fe9ca_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_fe9ca_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_fe9ca_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_fe9ca_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_fe9ca_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_fe9ca_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_fe9ca_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_fe9ca_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_fe9ca_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_fe9ca_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_fe9ca_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_fe9ca_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_fe9ca_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_fe9ca_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_fe9ca_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_fe9ca_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_fe9ca_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_train['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don', 'Dona'],
                        ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr', 'Mr'],inplace=True)

df_test['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don', 'Dona'],
                        ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr', 'Mr'],inplace=True)

df_train.groupby('Initial').mean()
# Out:
#          PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Initial
# Master    414.975000  0.575000  2.625000   4.574167  2.300000  1.375000
# Miss      411.741935  0.704301  2.284946  21.860000  0.698925  0.537634
# Mr        455.880907  0.162571  2.381853  32.739609  0.293006  0.151229
# Mrs       456.393701  0.795276  1.984252  35.981818  0.692913  0.818898
# Other     564.444444  0.111111  1.666667  45.888889  0.111111  0.111111
#
#              Fare  FamilySize
# Initial
# Master   3.340710    4.675000
# Miss     3.123713    2.236559
# Mr       2.651507    1.444234
# Mrs      3.443751    2.511811
# Other    2.641605    1.222222

# %% [markdown]
# Age의 평균을 이용해서 null 값을 입력할 것이다.

# %%
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Mr'),'Age'] = 33
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Mrs'),'Age'] = 36
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Master'),'Age'] = 5
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Miss'),'Age'] = 22
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Other'),'Age'] = 46

df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Mr'),'Age'] = 33
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Mrs'),'Age'] = 36
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Master'),'Age'] = 5
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Miss'),'Age'] = 22
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Other'),'Age'] = 46

# %% [markdown]
# ### (2) Embarked (탑승항구)
# ---
# null 값이 2개이므로, 가장 많은 S로 채움

# %%
# null 값 확인
print('Embarked has ', sum(df_train['Embarked'].isnull()), ' Null values')


# null=S 대체
df_train['Embarked'].fillna('S', inplace=True)
# Out:
# Embarked has  2  Null values

# %% [markdown]
# ## 3-2. Feature Engineering  _  ② 분류 작업

# %% [markdown]
# ### (1) AGE (나이)
# ---
# 10대, 20대, 30대 ... , 이상으로 총 7 분류로 나눔

# %%
df_train['Age_cat'] = 0
df_train.loc[df_train['Age'] < 10, 'Age_cat'] = 0
df_train.loc[(10 <= df_train['Age']) & (df_train['Age'] < 20), 'Age_cat'] = 1
df_train.loc[(20 <= df_train['Age']) & (df_train['Age'] < 30), 'Age_cat'] = 2
df_train.loc[(30 <= df_train['Age']) & (df_train['Age'] < 40), 'Age_cat'] = 3
df_train.loc[(40 <= df_train['Age']) & (df_train['Age'] < 50), 'Age_cat'] = 4
df_train.loc[(50 <= df_train['Age']) & (df_train['Age'] < 60), 'Age_cat'] = 5
df_train.loc[(60 <= df_train['Age']) & (df_train['Age'] < 70), 'Age_cat'] = 6
df_train.loc[70 <= df_train['Age'], 'Age_cat'] = 7

df_test['Age_cat'] = 0
df_test.loc[df_test['Age'] < 10, 'Age_cat'] = 0
df_test.loc[(10 <= df_test['Age']) & (df_test['Age'] < 20), 'Age_cat'] = 1
df_test.loc[(20 <= df_test['Age']) & (df_test['Age'] < 30), 'Age_cat'] = 2
df_test.loc[(30 <= df_test['Age']) & (df_test['Age'] < 40), 'Age_cat'] = 3
df_test.loc[(40 <= df_test['Age']) & (df_test['Age'] < 50), 'Age_cat'] = 4
df_test.loc[(50 <= df_test['Age']) & (df_test['Age'] < 60), 'Age_cat'] = 5
df_test.loc[(60 <= df_test['Age']) & (df_test['Age'] < 70), 'Age_cat'] = 6
df_test.loc[70 <= df_test['Age'], 'Age_cat'] = 7

# %%
def category_age(x):
    if x < 10:
        return 0
    elif x < 20:
        return 1
    elif x < 30:
        return 2
    elif x < 40:
        return 3
    elif x < 50:
        return 4
    elif x < 60:
        return 5
    elif x < 70:
        return 6
    else:
        return 7    
    
df_train['Age_cat_2'] = df_train['Age'].apply(category_age)

# %%
print('1번 방법, 2번 방법 둘다 같은 결과를 내면 True 줘야함 -> ', (df_train['Age_cat'] == df_train['Age_cat_2']).all())
# Out:
# 1번 방법, 2번 방법 둘다 같은 결과를 내면 True 줘야함 ->  True

# %%
df_train.drop(['Age', 'Age_cat_2'], axis=1, inplace=True)
df_test.drop(['Age'], axis=1, inplace=True)

# %% [markdown]
# ### (3) initial, embarked, sex
# ---
# - 이름, 항구, 성별 == 문자화 데이터
#
# - 사전 순으로 매핑

# %% [markdown]
# ### (3-1) Initial

# %%
df_train['Initial'] = df_train['Initial'].map({'Master': 0, 'Miss': 1, 'Mr': 2, 'Mrs': 3, 'Other': 4})
df_test['Initial'] = df_test['Initial'].map({'Master': 0, 'Miss': 1, 'Mr': 2, 'Mrs': 3, 'Other': 4})

# %% [markdown]
# ### (3-2) Embarked

# %%
# unique() : 고윳값 확인
df_train['Embarked'].unique()

# value_counts() : 고유한 행의 수
df_train['Embarked'].value_counts()

# map () : 여러 데이터를 한 번에 변형
# C:0, Q:1, S:2 로 변형
df_train['Embarked'] = df_train['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})
df_test['Embarked'] = df_test['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})

# %%
# Null 값이 있는 지 확인 -- 하나라도 있으면 True 반환
df_train['Embarked'].isnull().any()
# Out:
# False

# %% [markdown]
# ### (3-3) Sex

# %%
df_train['Sex'] = df_train['Sex'].map({'female': 0, 'male': 1})
df_test['Sex'] = df_test['Sex'].map({'female': 0, 'male': 1})

# %% [markdown]
# ## 3-3. Heatmap
# ---
# - heatmap을 이용해서 상관관계 확인
#
# - (-1,1) 사이 값을 얻음
#
# - 0은 상관관계 X

# %%
heatmap_data = df_train[['Survived', 'Pclass', 'Sex', 'Fare', 'Embarked', 'FamilySize', 'Initial', 'Age_cat']] 

colormap = plt.cm.RdBu
plt.figure(figsize=(14, 12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(heatmap_data.astype(float).corr(), linewidths=0.1, vmax=1.0,
           square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={"size": 16})

del heatmap_data

# %% [markdown]
# ## 3-4. one-hot encoding(원-핫 인코딩)
# - 목적 ) 성능을 높이기 위함
# - 내용 ) 단어의 벡터 표현 방식
# - 방법 )
#     1. **정수 인코딩** : 각 단어에 고유한 정수 부여
#     2. **단어 인코딩** : 고유한 정수를 인덱스로 + 해당 위치에 1 부여, 다른 단어의 인덱스 위치에는 0 부여

# %%
df_train = pd.get_dummies(df_train, columns=['Initial'], prefix='Initial')
df_test = pd.get_dummies(df_test, columns=['Initial'], prefix='Initial')

# %%
df_train = pd.get_dummies(df_train, columns=['Embarked'], prefix='Embarked')
df_test = pd.get_dummies(df_test, columns=['Embarked'], prefix='Embarked')

# %%
# 행 지움
df_train.drop(['PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin'], axis=1, inplace=True)
df_test.drop(['PassengerId', 'Name',  'SibSp', 'Parch', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %% [markdown]
# # 4-1. 모델 생성

# %% [markdown]
# ### 머신러닝 패키지를 불러옴
#
# (1) RandomForestClassifier : 과적합 현상을 개선한 앙상블 기법
#
# (2) metrics : 모델의 평가를 위해 씀
#
# (3) model_selection : traning set을 나눔
#
# ---
#
# 데이터의 모델 객체를 만들어줌

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics 
from sklearn.model_selection import train_test_split

# %%
X_train = df_train.drop('Survived', axis=1).values
target_label = df_train['Survived'].values
X_test = df_test.values

# %%
X_tr, X_vld, y_tr, y_vld = train_test_split(X_train, target_label, test_size=0.3, random_state=2018)

# %% [markdown]
# # 4-2. 성능확인

# %%
model = RandomForestClassifier()
model.fit(X_tr, y_tr)
prediction = model.predict(X_vld)

# %%
print('총 {}명 중 {:.2f}% 정확도로 생존을 맞춤'.format(y_vld.shape[0], 100 * metrics.accuracy_score(prediction, y_vld)))
# Out:
# 총 268명 중 82.46% 정확도로 생존을 맞춤

# %% [markdown]
# # 4-3. 객체 별 중요도

# %%
from pandas import Series

feature_importance = model.feature_importances_
Series_feat_imp = Series(feature_importance, index=df_test.columns)

plt.figure(figsize=(8, 8))
Series_feat_imp.sort_values(ascending=True).plot.barh()
plt.xlabel('Feature importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# # 4-4. 데이터의 예측
# ---
# 제출용 데이터인 submission의 결과를 확인하고 csv파일로 저장

# %%
submission = pd.read_csv('/kaggle/input/titanic/gender_submission.csv')

# %%
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
prediction = model.predict(X_test)
submission['Survived'] = prediction

# %%
submission.to_csv('./my_first_submission.csv', index=False)
