# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5)
import missingno as msno

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# # Data Import

# %%
df_train = pd.read_csv('/kaggle/input/titanic/train.csv')
df_test = pd.read_csv('/kaggle/input/titanic/test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
for col in df_train.columns:
    msg = 'column: {:>10}\t Percent of NaN value: {:.2f}%'.format(col, 100 * (df_train[col].isnull().sum() / df_train[col].shape[0]))
    print(msg)
    
    # isnull 사용해서 null 값 확인 & 결측값 수치 퍼센트로 표현
# Out:
# column: PassengerId	 Percent of NaN value: 0.00%
# column:   Survived	 Percent of NaN value: 0.00%
# column:     Pclass	 Percent of NaN value: 0.00%
# column:       Name	 Percent of NaN value: 0.00%
# column:        Sex	 Percent of NaN value: 0.00%
# column:        Age	 Percent of NaN value: 19.87%
# column:      SibSp	 Percent of NaN value: 0.00%
# column:      Parch	 Percent of NaN value: 0.00%
# column:     Ticket	 Percent of NaN value: 0.00%
# column:       Fare	 Percent of NaN value: 0.00%
# column:      Cabin	 Percent of NaN value: 77.10%
# column:   Embarked	 Percent of NaN value: 0.22%

# %%
for col in df_test.columns:
    msg = 'column: {:>10}\t Percent of NaN value: {:.2f}%'.format(col, 100 * (df_test[col].isnull().sum() / df_test[col].shape[0]))
    print(msg)
# Out:
# column: PassengerId	 Percent of NaN value: 0.00%
# column:     Pclass	 Percent of NaN value: 0.00%
# column:       Name	 Percent of NaN value: 0.00%
# column:        Sex	 Percent of NaN value: 0.00%
# column:        Age	 Percent of NaN value: 20.57%
# column:      SibSp	 Percent of NaN value: 0.00%
# column:      Parch	 Percent of NaN value: 0.00%
# column:     Ticket	 Percent of NaN value: 0.00%
# column:       Fare	 Percent of NaN value: 0.24%
# column:      Cabin	 Percent of NaN value: 78.23%
# column:   Embarked	 Percent of NaN value: 0.00%

# %% [markdown]
# **msno 라이브러리 (missingno)**
#
# - 결측치/결측값을 파악하기 쉽게 시각화 해주는 라이브러리
# - msno.bar : 막대그래프 형태로 결측치 시각화
# - msno.matrix : 매트릭스 형태로 결측치 시각화
#
# https://jaaamj.tistory.com/109 참조

# %%
msno.matrix(df=df_train.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2))
# 매트릭스 형태로 결측치 시각화
# Out:
# <AxesSubplot: >

# %%
msno.bar(df=df_train.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2))
# 바 형태로 결측치 시각화
# Out:
# <AxesSubplot: >

# %%
msno.bar(df=df_test.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2))
# 바 형태로 test set 결측치 시각화
# Out:
# <AxesSubplot: >

# %% [markdown]
# 📌
#
# *아래 코드 중 seaborn 라이브러리를 사용하는 모든 코드가 오류가 난다 ..*
#
# 'countplot() 오류' 혹은 'sns 라이브러리 함수' 등으로 검색해봤으나 아직 명확한 해결책을 찾지 못했다 ..
#
# 오류가 해결되면 업데이트 하겠다 .. ㅜㅜ

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

#생존자-사망자 수 시각화
 
#원형 그래프
df_train['Survived'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Pie plot - Survived')
ax[0].set_ylabel('')

#explode : 부채꼴이 파이 차트 중심을 벗어나는 정도
#autopct : 파이 차트에 표시되는 숫자 형태 지정

#막대 그래프
sns.countplot('Survived', data=df_train, ax=ax[1])
ax[1].set_title('Count plot - Survived')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 14
#       8 ax[0].set_ylabel('')
#      10 #explode : 부채꼴이 파이 차트 중심을 벗어나는 정도
#      11 #autopct : 파이 차트에 표시되는 숫자 형태 지정
#      12
#      13 #막대 그래프
# ---> 14 sns.countplot('Survived', data=df_train, ax=ax[1])
#      15 ax[1].set_title('Count plot - Survived')
#      17 plt.show()
#
# TypeError: countplot() got multiple values for argument 'data'

# %% [markdown]
# **Pclass별 생존률**

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).count()
# Pclass별 인원 수
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).sum()
# Pclass별 생존률
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')

#crosstab : 범주형 데이터 2개를 비교하는 교차 분석표 (위 예제에서는 생존자와 사망자의 수를 교차분석하였다.)
# Out:
# <style type="text/css">
# #T_00b2b_row0_col0, #T_00b2b_row1_col1, #T_00b2b_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_00b2b_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_00b2b_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_00b2b_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_00b2b_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_00b2b_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_00b2b_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_00b2b_row3_col0, #T_00b2b_row3_col1, #T_00b2b_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_00b2b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_00b2b_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_00b2b_level0_col1" class="col_heading level0 col1" >1</th>
# ...

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar()
# Out:
# <AxesSubplot: xlabel='Pclass'>

# %% [markdown]
# **Countplot func.(sns.countplot)**
# - 범주형 속성을 가지는 데이터들의 histogram을 보여주는 plot.
# - 종류별 count를 보여주는 방법
# - 특정 데이터에 대해서 지표 별 개수를 나타낸다.

# %%
#Pclass별 생존 인원수
y_position = 1.02
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train['Pclass'].value_counts().plot.bar(ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass', y=y_position)
ax[0].set_ylabel('Count')

# Pclass별 생존자, 사망자 수 비교
sns.countplot('Pclass', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Pclass: Survived vs Dead', y=y_position)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 9
#       6 ax[0].set_ylabel('Count')
#       8 # Pclass별 생존자, 사망자 수 비교
# ----> 9 sns.countplot('Pclass', hue='Survived', data=df_train, ax=ax[1])
#      10 ax[1].set_title('Pclass: Survived vs Dead', y=y_position)
#      11 plt.show()
#
# TypeError: countplot() got multiple values for argument 'data'

# %% [markdown]
# **성별 기준 생존률**

# %%
# 성별 생존자 수 
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')

# 성별 생존자 VS 사망자 수 비교
sns.countplot('Sex', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 7
#       4 ax[0].set_title('Survived vs Sex')
#       6 # 성별 생존자 VS 사망자 수 비교
# ----> 7 sns.countplot('Sex', hue='Survived', data=df_train, ax=ax[1])
#       8 ax[1].set_title('Sex: Survived vs Dead')
#       9 plt.show()
#
# TypeError: countplot() got multiple values for argument 'data'

# %%
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)

# %%
pd.crosstab(df_train['Sex'], df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_93b81_row0_col0, #T_93b81_row0_col2, #T_93b81_row1_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_93b81_row0_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_93b81_row1_col0 {
#   background-color: #2c9666;
#   color: #f1f1f1;
# }
# #T_93b81_row1_col2 {
#   background-color: #8bc566;
#   color: #000000;
# }
# #T_93b81_row2_col0, #T_93b81_row2_col1, #T_93b81_row2_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_93b81">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_93b81_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_93b81_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_93b81_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
# ...

# %% [markdown]
# **성별 & Pclass별 생존률**

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=df_train, 
               size=6, aspect=1.5)
# x축 Pclass, Y축 생존율, factor 성별
# factorplot을 이용하면 보여주고자 하는 목적에 어울리는 다양한 그래프 사용가능
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 sns.factorplot('Pclass', 'Survived', hue='Sex', data=df_train,
#       2                size=6, aspect=1.5)
#       3 # x축 Pclass, Y축 생존율, factor 성별
#       4 # factorplot을 이용하면 보여주고자 하는 목적에 어울리는 다양한 그래프 사용가능
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'

# %%
sns.factorplot(x='Sex', y='Survived', col='Pclass',
              data=df_train, satureation=.5,
               size=9, aspect=1
              )
# x축이 성별이고 y축이 생존률인 그래프 -> Pclass별로 출력
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 sns.factorplot(x='Sex', y='Survived', col='Pclass',
#       2               data=df_train, satureation=.5,
#       3                size=9, aspect=1
#       4               )
#       5 # x축이 성별이고 y축이 생존률인 그래프 -> Pclass별로 출력
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'

# %% [markdown]
# **나이별 생존률**

# %%
print('제일 나이 많은 탑승객 : {:.1f} Years'.format(df_train['Age'].max()))
print('제일 어린 탑승객 : {:.1f} Years'.format(df_train['Age'].min()))
print('탑승객 평균 나이 : {:.1f} Years'.format(df_train['Age'].mean()))
# Out:
# 제일 나이 많은 탑승객 : 80.0 Years
# 제일 어린 탑승객 : 0.4 Years
# 탑승객 평균 나이 : 29.7 Years

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(df_train[df_train['Survived'] == 1]['Age'], ax=ax)
sns.kdeplot(df_train[df_train['Survived'] == 0]['Age'], ax=ax)
plt.legend(['Survived == 1', 'Survived == 0'])
plt.show()

# kdeplot : 커널 밀도 추정 함수

# %%
# Age distribution withing classes
plt.figure(figsize=(8, 6))
df_train['Age'][df_train['Pclass'] == 1].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 2].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 3].plot(kind='kde')
# Pclass별 커널 밀도 측정

plt.xlabel('Age')
plt.title('Age Distribution within classes')
plt.legend(['1st Class', '2nd Class', '3rd Class'])

# %%
cummulate_survival_ratio = []
for i in range(1, 80):
    cummulate_survival_ratio.append(df_train[df_train['Age'] < i]['Survived'].sum() / len(df_train[df_train['Age'] < i]['Survived']))

    # 나이별 커널 밀도 측정    
plt.figure(figsize=(7, 7))
plt.plot(cummulate_survival_ratio)
plt.title('Survival rate change depending on range of Age', y=1.02)
plt.ylabel('Survival rate')
plt.xlabel('Range of Age(0~x)')
plt.show()

# %% [markdown]
# **Pclass, 성별, 나이별 비교**

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=df_train, scale='count', split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=df_train, scale='count', split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# violinplot : 일변량, 연속형 데이터의 분포를 설명하기 위해 사용되는 그래프
# 카테고리 값에 따른 각 분포의 실제 데이터, 전체 형상을 보여준다는 장점
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 f,ax=plt.subplots(1,2,figsize=(18,8))
# ----> 2 sns.violinplot("Pclass","Age", hue="Survived", data=df_train, scale='count', split=True,ax=ax[0])
#       3 ax[0].set_title('Pclass and Age vs Survived')
#       4 ax[0].set_yticks(range(0,110,10))
#
# TypeError: violinplot() got multiple values for argument 'data'

# %% [markdown]
# **탑승 항구별 생존자**

# %%
f, ax = plt.subplots(1, 1, figsize=(7, 7))
df_train[['Embarked', 'Survived']].groupby(['Embarked'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax)

#  탑승 항구별 생존자
# Out:
# <AxesSubplot: xlabel='Embarked'>

# %%
f,ax=plt.subplots(2, 2, figsize=(20,15))
sns.countplot('Embarked', data=df_train, ax=ax[0,0])

# 탑승 항구별 탑승 인원수
ax[0,0].set_title('(1) No. Of Passengers Boarded')
sns.countplot('Embarked', hue='Sex', data=df_train, ax=ax[0,1])
# 탑승 항구별 성별 탑승 인원수
ax[0,1].set_title('(2) Male-Female Split for Embarked')
sns.countplot('Embarked', hue='Survived', data=df_train, ax=ax[1,0])
# 탑승 항구별 생존률
ax[1,0].set_title('(3) Embarked vs Survived')
sns.countplot('Embarked', hue='Pclass', data=df_train, ax=ax[1,1])
# 탑승 항구별 Pclass 수
ax[1,1].set_title('(4) Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 f,ax=plt.subplots(2, 2, figsize=(20,15))
# ----> 2 sns.countplot('Embarked', data=df_train, ax=ax[0,0])
#       4 # 탑승 항구별 탑승 인원수
#       5 ax[0,0].set_title('(1) No. Of Passengers Boarded')
#
# TypeError: countplot() got multiple values for argument 'data'

# %%
# Familysize와 생존률 관계

f,ax=plt.subplots(1, 3, figsize=(40,10))
sns.countplot('FamilySize', data=df_train, ax=ax[0])

# 탑승자의 family size
ax[0].set_title('(1) No. Of Passengers Boarded', y=1.02)
sns.countplot('FamilySize', hue='Survived', data=df_train, ax=ax[1])

# 가족크기에 따른 생존확률 비교 
ax[1].set_title('(2) Survived countplot depending on FamilySize',  y=1.02)
df_train[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax[2])
ax[2].set_title('(3) Survived rate depending on FamilySize',  y=1.02)

plt.subplots_adj
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 4
#       1 # Familysize와 생존률 관계
#       3 f,ax=plt.subplots(1, 3, figsize=(40,10))
# ----> 4 sns.countplot('FamilySize', data=df_train, ax=ax[0])
#       6 # 탑승자의 family size
#       7 ax[0].set_title('(1) No. Of Passengers Boarded', y=1.02)
#
# TypeError: countplot() got multiple values for argument 'data'

# %% [markdown]
# **distplot func. (sns.distplot)**
#
# 커닐 밀도 그래프 (밀집도 그래프)
# - kde 인자
# - 주어진 데이터를 정규화 시켜 넓이가 1이 되도록 그린 그래프
# - 그래프와 x 축 사이의 면적이 1이 되도록 그리는 밀도 분포 함수
#
# 양탄자 그래프
# - rug 인자
# - 그래프의 축에 동일한 길이의 직선을 붙여 데이터의 밀집 정도를 표현한 그래프

# %%
# Fare (탑승 요금별) 
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
g = sns.distplot(df_train['Fare'], color='b', label='Skewness : {:.2f}'.format(df_train['Fare'].skew()), ax=ax)
g = g.legend(loc='best')

# %%
df_test.loc[df_test.Fare.isnull(), 'Fare'] = df_test['Fare'].mean() # testset 에 있는 nan value 를 평균값으로 치환합니다.

df_train['Fare'] = df_train['Fare'].map(lambda i: np.log(i) if i > 0 else 0)
df_test['Fare'] = df_test['Fare'].map(lambda i: np.log(i) if i > 0 else 0)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
g = sns.distplot(df_train['Fare'], color='b', label='Skewness : {:.2f}'.format(df_train['Fare'].skew()), ax=ax)
g = g.legend(loc='best')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket      Fare Cabin Embarked
# 0      0         A/5 21171  1.981001   NaN        S
# 1      0          PC 17599  4.266662   C85        C
# 2      0  STON/O2. 3101282  2.070022   NaN        S
# 3      0            113803  3.972177  C123        S
# 4      0            373450  2.085672   NaN        S

# %%
df_train['Ticket'].value_counts()
# Out:
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: Ticket, Length: 681, dtype: int64
